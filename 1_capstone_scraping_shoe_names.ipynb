# %% [markdown]
# # Capstone Project - Scraping shoe names

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
from time import time, sleep
from random import randint
from IPython.core.display import clear_output
from warnings import warn

# %%
# Use the requests library to get the html from the home page
res = requests.get('https://runrepeat.com/ranking/rankings-of-running-shoes?gender=men&page=')

# Parse the HTML from our URL into the BeautifulSoup parse tree format
soup = bs(res.content, 'lxml')

# %%
# Start with empty list
shoe_list = []

# Preparing the monitoring of the loop
start_time = time()
req = 0

# Loop through all 69 web pages of shoe listings
for n in range(1, 70):
    
    # Use the requests library to get the html from the web page
    res = requests.get(f'https://runrepeat.com/ranking/rankings-of-running-shoes?gender=men&page={n}')
    
    # Pause the loop
    sleep(randint(1, 6))
    
    # Monitor the requests
    req += 1
    elapsed_time = time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(req, req/elapsed_time))
    clear_output(wait = True)
    
    # Throw a warning for non-200 status codes
    if res.status_code != 200:
        warn('Request: {}; Status code: {}'.format(req, res.status_code))
        
    # Break the loop if the number of requests is greater than expected
    if req > 69:
        warn('Number of requests was greater than expected.')
        break

    # Parse the HTML from our URL into the BeautifulSoup parse tree format
    soup = bs(res.content, 'lxml')

    # Isolate the div that has all the shoe names and slugs
    shoes_section = soup.find('div', {'class': 'col-sm-9 shoes_container'})

    # Loop through each shoe name and slug in the div
    for name in shoes_section.find_all('div', {'class': 'product-name hidden-sm hidden-xs'}):

        # Start with an empty dictionary
        shoe_name = {}

        # Add name
        shoe_name['name'] = name.find('span', {'itemprop': 'name'}).text

        # Add slug from the href
        shoe_name['slug'] = name.find('a', {'target': '_self'})['href'].split('/')[-1]

        # Add shoe to our list of shoes
        shoe_list.append(shoe_name)
# Out:
# Request:69; Frequency: 0.16473979600741154 requests/s

# %%
# Check scraped data
shoe_list
# Out:
# [{'name': 'Nike Air Zoom Pegasus 35', 'slug': 'nike-air-zoom-pegasus-35'},
#  {'name': 'Brooks Ghost 11', 'slug': 'brooks-ghost-11'},
#  {'name': 'Asics Gel Kayano 25', 'slug': 'asics-gel-kayano-25'},
#  {'name': 'Brooks Adrenaline GTS 19', 'slug': 'brooks-adrenaline-gts-19'},
#  {'name': 'Adidas Ultra Boost', 'slug': 'adidas-ultra-boost'},
#  {'name': 'On Cloud', 'slug': 'on-cloud'},
#  {'name': 'Asics Gel Venture 6', 'slug': 'asics-gel-venture-6'},
#  {'name': 'Hoka One One Bondi 6', 'slug': 'hoka-one-one-bondi-6'},
#  {'name': 'Nike Downshifter 7', 'slug': 'nike-downshifter-7'},
#  {'name': 'Asics Gel Excite 6', 'slug': 'asics-gel-excite-6'},
#  {'name': 'Merrell Trail Glove 4', 'slug': 'merrell-trail-glove-4'},
#  {'name': 'Nike Air Zoom Pegasus 36', 'slug': 'nike-air-zoom-pegasus-36'},
#  {'name': 'Nike Air Zoom Winflo 6', 'slug': 'nike-air-zoom-winflo-6'},
#  {'name': 'Brooks Adrenaline GTS 18', 'slug': 'brooks-adrenaline-gts-18'},
#  {'name': 'Xero Shoes Prio', 'slug': 'xero-shoes-prio'},
#  {'name': 'New Balance 990 v4', 'slug': 'new-balance-990-v4'},
#  {'name': 'Nike Zoom Pegasus Turbo', 'slug': 'nike-zoom-pegasus-turbo'},
#  {'name': 'Asics Gel Contend 5', 'slug': 'asics-gel-contend-5'},
#  {'name': 'Asics Gel Nimbus 21', 'slug': 'asics-gel-nimbus-21'},
#  {'name': 'Nike Epic React Flyknit', 'slug': 'nike-epic-react-flyknit'},
#  {'name': 'Nike Zoom Fly', 'slug': 'nike-zoom-fly'},
#  {'name': 'Nike Revolution 4', 'slug': 'nike-revolution-4'},
#  {'name': 'Brooks Glycerin 16', 'slug': 'brooks-glycerin-16'},
#  {'name': 'Brooks Glycerin 17', 'slug': 'brooks-glycerin-17'},
#  {'name': 'Hoka One One Clifton 5', 'slug': 'hoka-one-one-clifton-5'},
#  {'name': 'Nike Free RN Flyknit 2018', 'slug': 'nike-free-rn-flyknit-2018'},
#  {'name': 'Nike Epic React Flyknit 2', 'slug': 'nike-epic-react-flyknit-2'},
#  {'name': 'Adidas Pure Boost Go', 'slug': 'adidas-pure-boost-go'},
#  {'name': 'Altra Escalante', 'slug': 'altra-escalante'},
#  {'name': 'Adidas Ultraboost 19', 'slug': 'adidas-ultraboost-19'},
#  {'name': 'Adidas Solar Boost', 'slug': 'adidas-solar-boost'},
#  {'name': 'Nike Zoom Fly Flyknit', 'slug': 'nike-zoom-fly-flyknit'},
#  {'name': 'Altra Escalante 1.5', 'slug': 'altra-escalante-15'},
#  {'name': 'Hoka One One Speedgoat 3', 'slug': 'hoka-one-one-speedgoat-3'},
#  {'name': 'Nike Air Zoom Pegasus 34', 'slug': 'nike-air-zoom-pegasus-34'},
#  {'name': 'Hoka One One Cavu', 'slug': 'hoka-one-one-cavu'},
#  {'name': 'Nike Free RN 2018', 'slug': 'nike-free-rn-2018'},
#  {'name': 'Mizuno Wave Rider 22', 'slug': 'mizuno-wave-rider-22'},
#  {'name': 'Brooks Revel', 'slug': 'brooks-revel'},
#  {'name': 'Asics Gel Venture 7', 'slug': 'asics-gel-venture-7'},
#  {'name': 'New Balance 880 v8', 'slug': 'new-balance-880-v8'},
#  {'name': 'New Balance Fresh Foam 1080 v9',
#   'slug': 'new-balance-fresh-foam-1080-v9'},
#  {'name': 'Brooks Ghost 10', 'slug': 'brooks-ghost-10'},
#  {'name': 'Saucony Kinvara 10', 'slug': 'saucony-kinvara-10'},
#  {'name': 'Nike Air VaporMax Flyknit', 'slug': 'nike-air-vapormax-flyknit'},
#  {'name': 'Asics Gel Quantum 90', 'slug': 'asics-gel-quantum-90'},
#  {'name': 'Brooks Launch 6', 'slug': 'brooks-launch-6'},
#  {'name': 'New Balance Fresh Foam Beacon',
#   'slug': 'new-balance-fresh-foam-beacon'},
#  {'name': 'Altra Lone Peak 4.0', 'slug': 'altra-lone-peak-40'},
#  {'name': 'Brooks Levitate 2', 'slug': 'brooks-levitate-2'},
#  {'name': 'Brooks Ghost 9', 'slug': 'brooks-ghost-9'},
#  {'name': 'Asics Gel Nimbus 20', 'slug': 'asics-gel-nimbus-20'},
#  {'name': 'Nike Air Zoom Winflo 5', 'slug': 'nike-air-zoom-winflo-5'},
#  {'name': 'Nike Air Zoom Vomero 14', 'slug': 'nike-air-zoom-vomero-14'},
#  {'name': 'Adidas AlphaBounce Instinct',
#   'slug': 'adidas-alphabounce-instinct'},
#  {'name': 'Saucony Liberty ISO', 'slug': 'saucony-liberty-iso'},
#  {'name': 'On Cloudflow', 'slug': 'on-cloudflow'},
#  {'name': 'Saucony Ride ISO', 'slug': 'saucony-ride-iso'},
#  {'name': 'Hoka One One Bondi 5', 'slug': 'hoka-one-one-bondi-5'},
#  {'name': 'Nike Epic Phantom React Flyknit',
#   'slug': 'nike-epic-phantom-react-flyknit'},
#  {'name': 'Brooks Beast 18', 'slug': 'brooks-beast-18'},
#  {'name': 'Asics Gel Kayano 24', 'slug': 'asics-gel-kayano-24'},
#  {'name': 'Salomon Speedcross 4', 'slug': 'salomon-speedcross-4'},
#  {'name': 'Asics Gel Kayano 26', 'slug': 'asics-gel-kayano-26'},
#  {'name': 'Nike Odyssey React', 'slug': 'nike-odyssey-react'},
#  {'name': 'New Balance 1540 v2', 'slug': 'new-balance-1540'},
#  {'name': 'Hoka One One Arahi 3', 'slug': 'hoka-one-one-arahi-3'},
#  {'name': 'New Balance 860 v9', 'slug': 'new-balance-860-v9'},
#  {'name': 'Asics Gel Contend 4', 'slug': 'asics-gel-contend-4'},
#  {'name': 'Adidas Adizero Adios Boost 3.0',
#   'slug': 'adidas-adizero-adios-boost'},
#  {'name': 'Adidas Ultra Boost ST', 'slug': 'adidas-ultra-boost-st'},
#  {'name': 'Adidas Adizero Boston Boost 7',
#   'slug': 'adidas-adizero-boston-boost-7'},
#  {'name': 'Saucony Cohesion 12', 'slug': 'saucony-cohesion-12'},
#  {'name': 'Brooks Pureflow 7', 'slug': 'brooks-pureflow-7'},
#  {'name': 'Adidas Pure Boost', 'slug': 'adidas-pure-boost'},
#  {'name': 'Brooks Revel 2', 'slug': 'brooks-revel-2'},
#  {'name': 'Asics Gel Cumulus 20', 'slug': 'asics-gel-cumulus-20'},
#  {'name': 'Saucony Kinvara 9', 'slug': 'saucony-kinvara-9'},
#  {'name': 'Brooks Ricochet', 'slug': 'brooks-ricochet'},
#  {'name': 'Nike Air Zoom Structure 21', 'slug': 'nike-air-zoom-structure-21'},
#  {'name': 'Adidas Duramo 9', 'slug': 'adidas-duramo-9'},
#  {'name': 'New Balance Fresh Foam Arishi',
#   'slug': 'new-balance-fresh-foam-arishi'},
#  {'name': 'Brooks Ravenna 9', 'slug': 'brooks-ravenna-9'},
#  {'name': 'Adidas Solar Glide', 'slug': 'adidas-solar-glide'},
#  {'name': 'Adidas AlphaBounce', 'slug': 'adidas-alphabounce'},
#  {'name': 'Nike Air Zoom Winflo 4', 'slug': 'nike-air-zoom-winflo-4'},
#  {'name': 'Nike Legend React', 'slug': 'nike-legend-react'},
#  {'name': 'Adidas Ultra Boost Uncaged', 'slug': 'adidas-ultra-boost-uncaged'},
#  {'name': 'Salomon Speedcross 5', 'slug': 'salomon-speedcross-5'},
#  {'name': 'Brooks Glycerin 15', 'slug': 'brooks-glycerin-15'},
#  {'name': 'Nike LunarGlide 9', 'slug': 'nike-lunarglide-9'},
#  {'name': 'Hoka One One Torrent', 'slug': 'hoka-one-one-torrent'},
#  {'name': 'Hoka One One Challenger 5 ATR',
#   'slug': 'hoka-one-one-challenger-5-atr'},
#  {'name': 'Adidas AlphaBounce Beyond', 'slug': 'adidas-alphabounce-beyond'},
#  {'name': 'Nike Renew Arena', 'slug': 'nike-renew-arena'},
#  {'name': 'Nike Zoom Fly SP', 'slug': 'nike-zoom-fly-sp'},
#  {'name': 'Mizuno Wave Sky 2', 'slug': 'mizuno-wave-sky-2'},
#  {'name': 'Nike Flex Experience RN 7', 'slug': 'nike-flex-experience-rn-7'},
#  {'name': 'Nike Zoom Pegasus Turbo 2', 'slug': 'nike-zoom-pegasus-turbo-2'},
#  {'name': 'New Balance Fresh Foam Vongo v3',
#   'slug': 'new-balance-fresh-foam-vongo-v3'},
#  {'name': 'Under Armour HOVR Sonic 2', 'slug': 'under-armour-hovr-sonic-2'},
#  {'name': 'Nike LunarGlide 8', 'slug': 'nike-lunarglide-8'},
#  {'name': 'Nike Odyssey React Flyknit 2',
#   'slug': 'nike-odyssey-react-flyknit-2'},
#  {'name': 'Nike Air Zoom Structure 22', 'slug': 'nike-air-zoom-structure-22'},
#  {'name': 'Saucony Excursion TR 12', 'slug': 'saucony-excursion-tr-12'},
#  {'name': 'Saucony Guide ISO', 'slug': 'saucony-guide-iso'},
#  {'name': 'Saucony Peregrine ISO', 'slug': 'saucony-peregrine-iso'},
#  {'name': 'Asics Gel Quantum 360', 'slug': 'asics-gel-quantum-360'},
#  {'name': 'New Balance Fresh Foam Arishi v2',
#   'slug': 'new-balance-fresh-foam-arishi-v2'},
#  {'name': 'Merrell Vapor Glove 3', 'slug': 'merrell-vapor-glove-3'},
#  {'name': 'Brooks Launch 5', 'slug': 'brooks-launch-5'},
#  {'name': 'Nike Flex RN 2017', 'slug': 'nike-flex-rn-2017'},
#  {'name': 'Asics Gel DS Trainer 24', 'slug': 'asics-gel-ds-trainer-24'},
#  {'name': 'New Balance Fresh Foam 1080 v8',
#   'slug': 'new-balance-fresh-foam-1080-v8'},
#  {'name': 'Mizuno Wave Inspire 15', 'slug': 'mizuno-wave-inspire-15'},
#  {'name': 'Brooks Transcend 6', 'slug': 'brooks-transcend-6'},
#  {'name': 'Nike Flex RN 2018', 'slug': 'nike-flex-rn-2018'},
#  {'name': 'Asics GT 2000 7', 'slug': 'asics-gt-2000-7'},
#  {'name': 'Saucony Guide ISO 2', 'slug': 'saucony-guide-iso-2'},
#  {'name': 'Hoka One One Arahi 2', 'slug': 'hoka-one-one-arahi-2'},
#  {'name': 'On Cloud X', 'slug': 'on-cloud-x'},
#  {'name': 'New Balance Fresh Foam Vongo',
#   'slug': 'new-balance-fresh-foam-vongo'},
#  {'name': 'New Balance FuelCell Impulse',
#   'slug': 'new-balance-fuelcell-impulse'},
#  {'name': 'New Balance 1400 v6', 'slug': 'new-balance-1400-v6'},
#  {'name': 'Salomon Trailster', 'slug': 'salomon-trailster'},
#  {'name': 'Saucony Triumph ISO 4', 'slug': 'saucony-triumph-iso-4'},
#  {'name': 'Nike Free RN', 'slug': 'nike-free-rn'},
#  {'name': 'Brooks Levitate', 'slug': 'brooks-levitate'},
#  {'name': 'Adidas Solar Glide ST', 'slug': 'adidas-solar-glide-st'},
#  {'name': 'Saucony Freedom ISO', 'slug': 'saucony-freedom-iso'},
#  {'name': 'On Cloudflyer', 'slug': 'on-cloudflyer'},
#  {'name': 'Hoka One One Clifton 1', 'slug': 'hoka-one-one-clifton-1'},
#  {'name': 'New Balance 880 v9', 'slug': 'new-balance-880-v9'},
#  {'name': 'Nike Flyknit Racer', 'slug': 'nike-flyknit-racer'},
#  {'name': 'New Balance 860 v8', 'slug': 'new-balance-860-v8'},
#  {'name': 'Hoka One One Mach', 'slug': 'hoka-one-one-mach'},
#  {'name': 'Adidas Ultra Boost Parley', 'slug': 'adidas-ultra-boost-parley'},
#  {'name': 'Skechers GOrun Ride 7', 'slug': 'skechers-gorun-ride-7'},
#  {'name': 'Hoka One One Gaviota', 'slug': 'hoka-one-one-gaviota'},
#  {'name': 'New Balance Fresh Foam Cruz',
#   'slug': 'new-balance-fresh-foam-cruz'},
#  {'name': 'Asics Gel Venture 5', 'slug': 'asics-gel-venture'},
#  {'name': 'Asics DynaFlyte', 'slug': 'asics-dynaflyte'},
#  {'name': 'Adidas Pure Boost DPR', 'slug': 'adidas-pure-boost-dpr'},
#  {'name': 'Under Armour Charged Bandit 3',
#   'slug': 'under-armour-charged-bandit-3'},
#  {'name': 'Nike Air Zoom Wildhorse 5', 'slug': 'nike-air-zoom-wildhorse-5'},
#  {'name': 'Brooks Ravenna 10', 'slug': 'brooks-ravenna-10'},
#  {'name': 'Altra Timp 1.5', 'slug': 'altra-timp-15'},
#  {'name': 'Mizuno Wave Inspire 14', 'slug': 'mizuno-wave-inspire-14'},
#  {'name': 'Asics GT 1000 4', 'slug': 'asics-gt-1000'},
#  {'name': 'New Balance Fresh Foam Zante v4',
#   'slug': 'new-balance-fresh-foam-zante-v4'},
#  {'name': 'Under Armour HOVR Sonic', 'slug': 'under-armour-hovr-sonic'},
#  {'name': 'Adidas Terrex CMTK GTX', 'slug': 'adidas-terrex-cmtk-gtx'},
#  {'name': 'Adidas Questar Ride', 'slug': 'adidas-questar-ride'},
#  {'name': 'Saucony Cohesion 10', 'slug': 'saucony-cohesion-10'},
#  {'name': 'Nike Zoom Vaporfly 4%', 'slug': 'nike-zoom-vaporfly-4'},
#  {'name': 'Salomon Sonic RA Max', 'slug': 'salomon-sonic-ra-max'},
#  {'name': 'Reebok Floatride Run Fast', 'slug': 'reebok-floatride-run-fast'},
#  {'name': 'Adidas Ultra Boost Laceless',
#   'slug': 'adidas-ultra-boost-laceless'},
#  {'name': 'Salomon XA Pro 3D', 'slug': 'salomon-xa-pro-3d'},
#  {'name': 'Asics Gel Nimbus 18', 'slug': 'asics-gel-nimbus'},
#  {'name': 'Adidas Supernova', 'slug': 'adidas-supernova'},
#  {'name': 'Asics GT 1000 7', 'slug': 'asics-gt-1000-7'},
#  {'name': 'Brooks Transcend 5', 'slug': 'brooks-transcend-5'},
#  {'name': 'Under Armour Charged Rogue', 'slug': 'under-armour-charged-rogue'},
#  {'name': 'Adidas Adizero Adios 4', 'slug': 'adidas-adizero-adios-4'},
#  {'name': 'Adidas Solar Drive', 'slug': 'adidas-solar-drive'},
#  {'name': 'Nike Free 5.0', 'slug': 'nike-free'},
#  {'name': 'Under Armour HOVR Infinite', 'slug': 'under-armour-hovr-infinite'},
#  {'name': 'Asics DynaFlyte 3', 'slug': 'asics-dynaflyte-3'},
#  {'name': 'Saucony Triumph ISO 5', 'slug': 'saucony-triumph-iso-5'},
#  {'name': 'Hoka One One Clifton 4', 'slug': 'hoka-one-one-clifton-4'},
#  {'name': 'Nike Air Zoom Vomero 13', 'slug': 'nike-air-zoom-vomero-13'},
#  {'name': 'Salomon Sense Ride', 'slug': 'salomon-sense-ride'},
#  {'name': 'Topo Athletic MT-2', 'slug': 'topo-athletic-mt-2'},
#  {'name': 'Adidas Pureboost RBL', 'slug': 'adidas-pureboost-rbl'},
#  {'name': 'Altra Timp', 'slug': 'altra-timp'},
#  {'name': 'Adidas Asweego', 'slug': 'adidas-asweego'},
#  {'name': 'Altra Escalante Racer', 'slug': 'altra-escalante-racer'},
#  {'name': 'Adidas Energy Boost 3', 'slug': 'adidas-energy-boost'},
#  {'name': 'Hoka One One Hupana', 'slug': 'hoka-one-one-hupana'},
#  {'name': 'Adidas Terrex Agravic', 'slug': 'adidas-terrex-agravic'},
#  {'name': 'Saucony Omni ISO', 'slug': 'saucony-omni-iso'},
#  {'name': 'Asics GT 2000 6', 'slug': 'asics-gt-2000-6'},
#  {'name': 'Nike Free RN Flyknit', 'slug': 'nike-free-rn-flyknit'},
#  {'name': 'Adidas Ultraboost S&L', 'slug': 'adidas-ultraboost-sl'},
#  {'name': 'Brooks Ghost 12', 'slug': 'brooks-ghost-12'},
#  {'name': 'Saucony Ride 10', 'slug': 'saucony-ride-10'},
#  {'name': 'Salomon Sense Ride 2', 'slug': 'salomon-sense-ride-2'},
#  {'name': 'Asics DynaFlyte 2', 'slug': 'asics-dynaflyte-2'},
#  {'name': 'Brooks Addiction 13', 'slug': 'brooks-addiction-13'},
#  {'name': 'New Balance 840 v4', 'slug': 'new-balance-840-v4'},
#  {'name': 'Adidas Terrex Agravic Speed',
#   'slug': 'adidas-terrex-agravic-speed'},
#  {'name': 'Mizuno Wave Sky', 'slug': 'mizuno-wave-sky'},
#  {'name': 'Asics FuzeTora Twist', 'slug': 'asics-fuzetora-twist'},
#  {'name': 'Adidas Terrex Tracerocker', 'slug': 'adidas-terrex-tracerocker'},
#  {'name': 'Adidas Runfalcon', 'slug': 'adidas-runfalcon'},
#  {'name': 'New Balance 890 v6', 'slug': 'new-balance-890-v6'},
#  {'name': 'Brooks PureCadence 7', 'slug': 'brooks-purecadence-7'},
#  {'name': 'Saucony Cohesion 11', 'slug': 'saucony-cohesion-11'},
#  {'name': 'Nike Revolution 3', 'slug': 'nike-revolution-3'},
#  {'name': 'Nike Air Max 2017', 'slug': 'nike-air-max-2017'},
#  {'name': 'Hoka One One Speedgoat 2', 'slug': 'hoka-one-one-speedgoat-2'},
#  {'name': 'Hoka One One Clifton 3', 'slug': 'hoka-one-one-clifton-3'},
#  {'name': 'Salomon X-Mission 3', 'slug': 'salomon-x-mission-3'},
#  {'name': 'Adidas Ultra Boost All Terrain',
#   'slug': 'adidas-ultra-boost-all-terrain'},
#  {'name': 'Adidas Ultraboost Clima', 'slug': 'adidas-ultraboost-clima'},
#  {'name': 'New Balance 840 v3', 'slug': 'new-balance-840'},
#  {'name': 'New Balance Fresh Foam Cruz v2 Sport',
#   'slug': 'new-balance-fresh-foam-cruz-v2-sport'},
#  {'name': 'Altra Torin 3.0', 'slug': 'altra-torin-30'},
#  {'name': 'Salomon Speedcross 3', 'slug': 'salomon-speedcross'},
#  {'name': 'Asics Gel Kinsei 6', 'slug': 'asics-gel-kinsei'},
#  {'name': 'Saucony Cohesion 9', 'slug': 'saucony-cohesion'},
#  {'name': 'Nike Air Zoom Pegasus 33', 'slug': 'nike-air-zoom-pegasus-33'},
#  {'name': 'On Cloudventure', 'slug': 'on-cloudventure'},
#  {'name': 'Salomon Sense Ride GTX Invisible Fit',
#   'slug': 'salomon-sense-ride-gtx-invisible-fit'},
#  {'name': 'Saucony Fastwitch 8', 'slug': 'saucony-fastwitch-8'},
#  {'name': 'Skechers GOrun 600', 'slug': 'skechers-gorun-600'},
#  {'name': 'Hoka One One Arahi', 'slug': 'hoka-one-one-arahi'},
#  {'name': 'Saucony Peregrine 8', 'slug': 'saucony-peregrine-8'},
#  {'name': 'Hoka One One Carbon X', 'slug': 'hoka-one-one-carbon-x'},
#  {'name': 'Brooks Adrenaline GTS 17', 'slug': 'brooks-adrenaline-gts-17'},
#  {'name': 'Nike Renew Rival', 'slug': 'nike-renew-rival'},
#  {'name': 'Under Armour Charged Escape',
#   'slug': 'under-armour-charged-escape'},
#  {'name': 'Adidas Aerobounce 2 ', 'slug': 'adidas-aerobounce-2'},
#  {'name': 'Altra Paradigm 4.0', 'slug': 'altra-paradigm-40'},
#  {'name': 'New Balance 880 v7', 'slug': 'new-balance-880-v7'},
#  {'name': 'New Balance Fresh Foam 980', 'slug': 'new-balance-fresh-foam-980'},
#  {'name': 'Nike Flyknit Air Max 2015', 'slug': 'nike-flyknit-air-max'},
#  {'name': 'On Cloudace', 'slug': 'on-cloudace'},
#  {'name': 'Nike Air Max 2016', 'slug': 'nike-air-max'},
#  {'name': 'New Balance Fresh Foam Zante Pursuit',
#   'slug': 'new-balance-fresh-foam-zante-pursuit'},
#  {'name': 'Mizuno Wave Rider 20', 'slug': 'mizuno-wave-rider-20'},
#  {'name': 'Saucony Freedom ISO 2', 'slug': 'saucony-freedom-iso-2'},
#  {'name': 'Adidas Adizero Tempo 9', 'slug': 'adidas-adizero-tempo-9'},
#  {'name': 'Mizuno Wave Rider 21', 'slug': 'mizuno-wave-rider-21'},
#  {'name': 'Asics FuzeX Lyte 2', 'slug': 'asics-fuzex-lyte-2'},
#  {'name': 'Asics Gel Quantum 180', 'slug': 'asics-gel-quantum-180'},
#  {'name': 'Nike Air Zoom Terra Kiger 5',
#   'slug': 'nike-air-zoom-terra-kiger-5'},
#  {'name': 'La Sportiva Bushido', 'slug': 'la-sportiva-bushido'},
#  {'name': 'Skechers GOrun Razor 3 Hyper ',
#   'slug': 'skechers-gorun-razor-3-hyper'},
#  {'name': 'Salomon XA Elevate', 'slug': 'salomon-xa-elevate'},
#  {'name': 'Nike Air Zoom Pegasus 35 Shield',
#   'slug': 'nike-air-zoom-pegasus-35-shield'},
#  {'name': 'New Balance Fresh Foam Zante v3',
#   'slug': 'new-balance-fresh-foam-zante-v3'},
#  {'name': 'La Sportiva Ultra Raptor', 'slug': 'la-sportiva-ultra-raptor'},
#  {'name': 'Altra Superior 4.0', 'slug': 'altra-superior-40'},
#  {'name': 'New Balance 680 v4', 'slug': 'new-balance-680-v4'},
#  {'name': 'New Balance 870 v4', 'slug': 'new-balance-870'},
#  {'name': 'Mizuno Wave Shadow', 'slug': 'mizuno-wave-shadow'},
#  {'name': 'Asics GT 2000 4', 'slug': 'asics-gt-2000'},
#  {'name': 'Nike Zoom All Out Low', 'slug': 'nike-zoom-all-out-low'},
#  {'name': 'Mizuno Wave Shadow 2', 'slug': 'mizuno-wave-shadow-2'},
#  {'name': 'New Balance Minimus 10 v1', 'slug': 'new-balance-minimus-10-v1'},
#  {'name': 'Nike Free RN 2017', 'slug': 'nike-free-rn-2017'},
#  {'name': 'Nike Flyknit Lunar 3', 'slug': 'nike-flyknit-lunar-3'},
#  {'name': 'Inov-8 Trail Talon 235', 'slug': 'inov-8-trail-talon-235'},
#  {'name': 'Asics GT 2000 5', 'slug': 'asics-gt-2000-5'},
#  {'name': 'New Balance FuelCell', 'slug': 'new-balance-fuelcell'},
#  {'name': 'Brooks Bedlam', 'slug': 'brooks-bedlam'},
#  {'name': 'Asics Roadhawk FF 2', 'slug': 'asics-roadhawk-ff-2'},
#  {'name': 'Adidas Supernova Glide Boost 8',
#   'slug': 'adidas-supernova-glide-boost'},
#  {'name': 'Hoka One One Akasa', 'slug': 'hoka-one-one-akasa'},
#  {'name': 'Asics Gel Noosa Tri 11', 'slug': 'asics-gel-noosa-tri-11'},
#  {'name': 'Nike Free RN Commuter 2018', 'slug': 'nike-free-rn-commuter-2018'},
#  {'name': 'Nike Air VaporMax Flyknit 2',
#   'slug': 'nike-air-vapormax-flyknit-2'},
#  {'name': 'Nike Downshifter 6', 'slug': 'nike-downshifter'},
#  {'name': 'Asics Gel Kahana 8', 'slug': 'asics-gel-kahana-8'},
#  {'name': 'Saucony Guide 10', 'slug': 'saucony-guide-10'},
#  {'name': 'Saucony Guide 9', 'slug': 'saucony-guide'},
#  {'name': 'Nike Free Flyknit 4.0', 'slug': 'nike-free-flyknit-4-0'},
#  {'name': 'Asics Gel FujiTrabuco 7', 'slug': 'asics-gel-fujitrabuco-7'},
#  {'name': 'Reebok Floatride Run', 'slug': 'reebok-floatride-run'},
#  {'name': 'Nike FS Lite Run 3', 'slug': 'nike-fs-lite-run'},
#  {'name': 'Adidas Ultraboost Mid', 'slug': 'adidas-ultraboost-mid'},
#  {'name': 'Merrell Trail Glove 5', 'slug': 'merrell-trail-glove-5'},
#  {'name': 'Saucony Hurricane ISO 4', 'slug': 'saucony-hurricane-iso-4'},
#  {'name': 'New Balance Fresh Foam Roav',
#   'slug': 'new-balance-fresh-foam-roav'},
#  {'name': 'Asics Alpine XT', 'slug': 'asics-alpine-xt'},
#  {'name': 'Under Armour HOVR Phantom SE',
#   'slug': 'under-armour-hovr-phantom-se'},
#  {'name': 'Brooks Asteria', 'slug': 'brooks-asteria'},
#  {'name': 'Adidas Terrex Tracerocker GTX',
#   'slug': 'adidas-terrex-tracerocker-gtx'},
#  {'name': 'Saucony Ride ISO 2', 'slug': 'saucony-ride-iso-2'},
#  {'name': 'Mizuno Wave Paradox 2', 'slug': 'mizuno-wave-paradox'},
#  {'name': 'Nike Free RN Motion Flyknit 2017',
#   'slug': 'nike-free-rn-motion-flyknit-2017'},
#  {'name': 'The North Face Ultra 109 GTX',
#   'slug': 'the-north-face-ultra-109-gtx'},
#  {'name': 'On Cloudswift', 'slug': 'on-cloudswift'},
#  {'name': 'Nike FS Lite Run 4', 'slug': 'nike-fs-lite-run-4'},
#  {'name': 'Under Armour Micro G Pursuit',
#   'slug': 'under-armour-micro-g-pursuit'},
#  {'name': 'New Balance Fresh Foam Kaymin TRL',
#   'slug': 'new-balance-fresh-foam-kaymin-trl'},
#  {'name': 'Salomon Sonic RA', 'slug': 'salomon-sonic-ra'},
#  {'name': 'Brooks Caldera', 'slug': 'brooks-caldera'},
#  {'name': 'Under Armour Surge SE', 'slug': 'under-armour-surge-se'},
#  {'name': 'Asics Gel Excite 4', 'slug': 'asics-gel-excite-4'},
#  {'name': 'Nike Flex Experience 4', 'slug': 'nike-flex-experience'},
#  {'name': 'Altra Olympus 3.0', 'slug': 'altra-olympus-30'},
#  {'name': 'Under Armour Fat Tire', 'slug': 'under-armour-fat-tire'},
#  {'name': 'Adidas AlphaBounce RC 2.0', 'slug': 'adidas-alphabounce-rc-20'},
#  {'name': 'Nike LunarGlide 7', 'slug': 'nike-lunarglide'},
#  {'name': 'Asics Gel Quantum 180 3', 'slug': 'asics-gel-quantum-180-3'},
#  {'name': 'Saucony Omni 13', 'slug': 'saucony-omni-13'},
#  {'name': 'Nike Air Zoom Vomero 12', 'slug': 'nike-air-zoom-vomero-12'},
#  {'name': 'Under Armour Charged Intake 3',
#   'slug': 'under-armour-charged-intake-3'},
#  {'name': 'Adidas Purebounce+', 'slug': 'adidas-purebounce'},
#  {'name': 'Nike Air VaporMax Run Utility',
#   'slug': 'nike-air-vapormax-run-utility'},
#  {'name': 'Asics Gel Kayano 25 SP', 'slug': 'asics-gel-kayano-25-sp'},
#  {'name': 'New Balance 860 v7', 'slug': 'new-balance-860-v7'},
#  {'name': 'Hoka One One Stinson ATR 4', 'slug': 'hoka-one-one-stinson-atr-4'},
#  {'name': 'Under Armour SpeedForm Gemini 2',
#   'slug': 'under-armour-speedform-gemini'},
#  {'name': 'Nike Air Zoom Pegasus 36 Trail',
#   'slug': 'nike-air-zoom-pegasus-36-trail'},
#  {'name': 'Saucony Excursion TR 9', 'slug': 'saucony-excursion-tr'},
#  {'name': 'Nike Flex Experience RN 6', 'slug': 'nike-flex-experience-rn-6'},
#  {'name': 'Asics Gel Fortitude 8', 'slug': 'asics-gel-fortitude-8'},
#  {'name': 'Under Armour HOVR Phantom Connected',
#   'slug': 'under-armour-hovr-phantom-connected'},
#  {'name': 'Altra Torin 4', 'slug': 'altra-torin-4'},
#  {'name': 'Salomon Sense Pro Max', 'slug': 'salomon-sense-pro-max'},
#  {'name': 'New Balance Rubix', 'slug': 'new-balance-rubix'},
#  {'name': 'Altra Torin 3.5 Knit', 'slug': 'altra-torin-35-knit'},
#  {'name': 'Nike Air Zoom Pegasus 34 FlyEase',
#   'slug': 'nike-air-zoom-pegasus-34-flyease'},
#  {'name': 'Nike Joyride Run Flyknit', 'slug': 'nike-joyride-run-flyknit'},
#  {'name': 'Adidas Adizero Prime LTD', 'slug': 'adidas-adizero-prime-ltd'},
#  {'name': 'Hoka One One Gaviota 2', 'slug': 'hoka-one-one-gaviota-2'},
#  {'name': 'Adidas Supernova Sequence Boost 9',
#   'slug': 'adidas-supernova-sequence-boost-9'},
#  {'name': 'Altra Solstice', 'slug': 'altra-solstice'},
#  {'name': 'Adidas Solar Drive ST', 'slug': 'adidas-solar-drive-st'},
#  {'name': 'New Balance FuelCore Nitrel Trail',
#   'slug': 'new-balance-fuelcore-nitrel-trail'},
#  {'name': 'Asics Gel Torrance', 'slug': 'asics-gel-torrance'},
#  {'name': 'Nike ZoomX Vaporfly Next%', 'slug': 'nike-zoomx-vaporfly-next'},
#  {'name': 'Under Armour Charged Escape 2',
#   'slug': 'under-armour-charged-escape-2'},
#  {'name': 'Salomon Speedcross 4 GTX', 'slug': 'salomon-speedcross-4-gtx'},
#  {'name': 'Brooks Beast 16', 'slug': 'brooks-beast-16'},
#  {'name': 'Nike Air Zoom Terra Kiger 4',
#   'slug': 'nike-air-zoom-terra-kiger-4'},
#  {'name': 'Adidas Rockadia Trail', 'slug': 'adidas-rockadia-trail'},
#  {'name': 'Inov-8 Roclite 290', 'slug': 'inov-8-roclite-290'},
#  {'name': 'Nike Free RN Distance', 'slug': 'nike-free-rn-distance'},
#  {'name': 'Skechers GOrun Fast - Valor', 'slug': 'skechers-gorun-fast-valor'},
#  {'name': 'Adidas Questar TND', 'slug': 'adidas-questar-tnd'},
#  {'name': 'Brooks Cascadia 12', 'slug': 'brooks-cascadia-12'},
#  {'name': 'Saucony Kineta Relay', 'slug': 'saucony-kineta-relay'},
#  {'name': 'New Balance 1260 v7', 'slug': 'new-balance-1260-v7'},
#  {'name': 'New Balance 680 v3', 'slug': 'new-balance-680'},
#  {'name': 'Altra King MT', 'slug': 'altra-king-mt'},
#  {'name': 'Brooks Ghost 11 GTX', 'slug': 'brooks-ghost-11-gtx'},
#  {'name': 'Altra One 2.5', 'slug': 'altra-one'},
#  {'name': 'Asics Gel Sonoma 4', 'slug': 'asics-gel-sonoma-4'},
#  {'name': 'La Sportiva Kaptiva', 'slug': 'la-sportiva-kaptiva'},
#  {'name': 'Altra Lone Peak 3.5', 'slug': 'altra-lone-peak-35'},
#  {'name': 'Hoka One One Challenger 4 ATR',
#   'slug': 'hoka-one-one-challenger-4-atr'},
#  {'name': 'Nike Air Zoom Odyssey 2', 'slug': 'nike-air-zoom-odyssey-2'},
#  {'name': 'Asics Gel Scram 4', 'slug': 'asics-gel-scram-4'},
#  {'name': 'Asics Gel Kayano 23', 'slug': 'asics-gel-kayano-23'},
#  {'name': 'The North Face Ultra 110 GTX',
#   'slug': 'the-north-face-ultra-110-gtx'},
#  {'name': 'New Balance Fresh Foam 1080 v7',
#   'slug': 'new-balance-fresh-foam-1080-v7'},
#  {'name': 'Adidas Adizero Boston Boost 6',
#   'slug': 'adidas-adizero-boston-boost'},
#  {'name': 'Altra Torin IQ', 'slug': 'altra-torin-iq'},
#  {'name': 'Brooks PureGrit 7', 'slug': 'brooks-puregrit-7'},
#  {'name': 'La Sportiva Akasha', 'slug': 'la-sportiva-akasha'},
#  {'name': 'Nike LunarEpic Flyknit', 'slug': 'nike-lunarepic-flyknit'},
#  {'name': 'Altra Superior 3.5', 'slug': 'altra-superior-35'},
#  {'name': 'La Sportiva Akyra', 'slug': 'la-sportiva-akyra'},
#  {'name': 'Mizuno WaveKnit R2', 'slug': 'mizuno-waveknit-r2'},
#  {'name': 'Brooks Cascadia 14', 'slug': 'brooks-cascadia-14'},
#  {'name': 'Asics HyperGel Kenzen', 'slug': 'asics-hypergel-kenzen'},
#  {'name': 'Mizuno Wave Inspire 12', 'slug': 'mizuno-wave-inspire'},
#  {'name': 'Asics Gel DS Trainer 23', 'slug': 'asics-gel-ds-trainer-23'},
#  {'name': 'Reebok Driftium Ride', 'slug': 'reebok-driftium-ride'},
#  {'name': 'Vibram FiveFingers KSO EVO', 'slug': 'vibram-fivefingers-kso-evo'},
#  {'name': 'Asics Gel Kayano 25 Lite-Show',
#   'slug': 'asics-gel-kayano-25-lite-show'},
#  {'name': 'Nike Air Zoom Pegasus 31', 'slug': 'nike-air-zoom-pegasus-31'},
#  {'name': 'Salomon XA Pro 3D GTX', 'slug': 'salomon-xa-pro-3d-gtx'},
#  {'name': 'Asics GT 1000 6', 'slug': 'asics-gt-1000-6'},
#  {'name': 'Nike LunarEpic Low Flyknit 2',
#   'slug': 'nike-lunarepic-low-flyknit-2'},
#  {'name': 'Hoka One One Bondi Leather', 'slug': 'hoka-one-one-bondi-leather'},
#  {'name': 'Salomon XA Pro 3D CS WP', 'slug': 'salomon-xa-pro-3d-cs-wp'},
#  {'name': 'Hoka One One Hupana 2', 'slug': 'hoka-one-one-hupana-2'},
#  {'name': 'Merrell Bare Access 4', 'slug': 'merrell-bare-access'},
#  {'name': 'Reebok Harmony Road', 'slug': 'reebok-harmony-road'},
#  {'name': 'Hoka One One Evo Mafate', 'slug': 'hoka-one-one-evo-mafate'},
#  {'name': 'Brooks Hyperion', 'slug': 'brooks-hyperion'},
#  {'name': 'Brooks Caldera 3', 'slug': 'brooks-caldera-3'},
#  {'name': 'Adidas Galaxy 4', 'slug': 'adidas-galaxy-4'},
#  {'name': 'On Cloudsurfer', 'slug': 'on-cloudsurfer'},
#  {'name': 'Adidas Terrex Swift R GTX', 'slug': 'adidas-terrex-swift-r-gtx'},
#  {'name': 'Adidas Supernova Trail', 'slug': 'adidas-supernova-trail'},
#  {'name': 'New Balance 860 v6', 'slug': 'new-balance-860'},
#  {'name': 'Jordan 89 Racer', 'slug': 'jordan-89-racer'},
#  {'name': 'Under Armour SpeedForm Gemini 3',
#   'slug': 'under-armour-speedform-gemini-3'},
#  {'name': 'Brooks Anthem', 'slug': 'brooks-anthem'},
#  {'name': 'Asics Roadhawk FF', 'slug': 'asics-roadhawk-ff'},
#  {'name': 'Puma Carson 2 X Knit', 'slug': 'puma-carson-2-x-knit'},
#  {'name': 'Saucony Zealot ISO', 'slug': 'saucony-zealot-iso'},
#  {'name': 'Under Armour Micro G Assert 7',
#   'slug': 'under-armour-micro-g-assert-7'},
#  {'name': 'Adidas Kanadia 8', 'slug': 'adidas-kanadia-8'},
#  {'name': '361 Degrees Strata 2', 'slug': '361-degrees-strata-2'},
#  {'name': 'New Balance 1260 v5', 'slug': 'new-balance-1260'},
#  {'name': 'La Sportiva Mutant', 'slug': 'la-sportiva-mutant'},
#  {'name': 'Asics Gel Nimbus 19', 'slug': 'asics-gel-nimbus-19'},
#  {'name': 'Nike Lunar Apparent', 'slug': 'nike-lunar-apparent'},
#  {'name': 'Adidas Response Trail', 'slug': 'adidas-response-trail'},
#  {'name': 'Asics GT Xpress', 'slug': 'asics-gt-xpress'},
#  {'name': 'Salomon X Mission 2', 'slug': 'salomon-x-mission'},
#  {'name': 'Nike Air Zoom Pegasus 32', 'slug': 'nike-air-zoom-pegasus'},
#  {'name': 'Altra Olympus 2.5', 'slug': 'altra-olympus-25'},
#  {'name': 'Merrell Bare Access Flex', 'slug': 'merrell-bare-access-flex'},
#  {'name': 'Asics Patriot 10', 'slug': 'asics-patriot-10'},
#  {'name': 'Nike Free RN 5.0', 'slug': 'nike-free-rn-50'},
#  {'name': 'Reebok All Terrain Craze', 'slug': 'reebok-all-terrain-craze'},
#  {'name': 'Brooks Dyad 10', 'slug': 'brooks-dyad-10'},
#  {'name': 'Salomon Predict RA', 'slug': 'salomon-predict-ra'},
#  {'name': 'Adidas Adizero Takumi-Sen 3', 'slug': 'adidas-adizero-takumi-sen'},
#  {'name': 'Asics Gel Kenun', 'slug': 'asics-gel-kenun'},
#  {'name': 'Nike Air Max 2015', 'slug': 'nike-air-max-2015'},
#  {'name': 'Saucony Stabil CS 3', 'slug': 'saucony-stabil-cs'},
#  {'name': 'Asics Gel Quantum 360 4', 'slug': 'asics-gel-quantum-360-4'},
#  {'name': 'Hoka One One Tor Ultra Hi WP',
#   'slug': 'hoka-one-one-tor-ultra-hi-wp'},
#  {'name': 'Under Armour SpeedForm Europa',
#   'slug': 'under-armour-speedform-europa'},
#  {'name': 'Nike Flex Fury 2', 'slug': 'nike-flex-fury-2'},
#  {'name': 'Saucony Omni 16', 'slug': 'saucony-omni-16'},
#  {'name': 'Topo Athletic Runventure 2', 'slug': 'topo-athletic-runventure-2'},
#  {'name': 'Nike Renew Rival Shield', 'slug': 'nike-renew-rival-shield'},
#  {'name': 'New Balance Vazee Pace', 'slug': 'new-balance-vazee-pace'},
#  {'name': 'Asics Gel Contend 3', 'slug': 'asics-gel-contend'},
#  {'name': 'Asics Gel Quantum 180 4', 'slug': 'asics-gel-quantum-180-4'},
#  {'name': 'Nike LunarConverge', 'slug': 'nike-lunarconverge'},
#  {'name': 'Asics Gel Flux 5', 'slug': 'asics-gel-flux-5'},
#  {'name': 'Hoka One One Conquest 2', 'slug': 'hoka-one-one-conquest'},
#  {'name': 'Nike Free RN Flyknit 2017', 'slug': 'nike-free-rn-flyknit-2017'},
#  {'name': 'Asics Gel Nimbus 17', 'slug': 'asics-gel-nimbus-17'},
#  {'name': 'New Balance Fresh Foam Vongo v2',
#   'slug': 'new-balance-fresh-foam-vongo-v2'},
#  {'name': 'New Balance 940 v3', 'slug': 'new-balance-940-v3'},
#  {'name': 'New Balance Fresh Foam Hierro v4',
#   'slug': 'new-balance-fresh-foam-hierro-v4'},
#  {'name': 'Nike LunarSolo', 'slug': 'nike-lunarsolo'},
#  {'name': 'Jordan 88 Racer', 'slug': 'jordan-88-racer'},
#  {'name': 'Asics Gel Vanisher', 'slug': 'asics-gel-vanisher'},
#  {'name': 'Reebok Zigwild TR 5.0', 'slug': 'reebok-zigwild-tr-50'},
#  {'name': 'New Balance Fresh Foam 1080 v6',
#   'slug': 'new-balance-fresh-foam-1080'},
#  {'name': 'Mizuno Wave Prophecy 7', 'slug': 'mizuno-wave-prophecy-7'},
#  {'name': 'Asics Gel Foundation 13', 'slug': 'asics-gel-foundation-13'},
#  {'name': 'Adidas Aerobounce PR', 'slug': 'adidas-aerobounce-pr'},
#  {'name': 'Jordan Zoom Tenacity 88', 'slug': 'jordan-zoom-tenacity-88'},
#  {'name': 'Mizuno Wave Catalyst', 'slug': 'mizuno-wave-catalyst'},
#  {'name': 'Brooks Adrenaline GTS 16', 'slug': 'brooks-adrenaline-gts'},
#  {'name': 'Saucony Triumph ISO 2', 'slug': 'saucony-triumph-iso'},
#  {'name': 'La Sportiva Bushido II', 'slug': 'la-sportiva-bushido-ii'},
#  {'name': 'New Balance Summit Unknown', 'slug': 'new-balance-summit-unknown'},
#  {'name': 'New Balance Fresh Foam Kaymin',
#   'slug': 'new-balance-fresh-foam-kaymin'},
#  {'name': 'Saucony Fastwitch 9', 'slug': 'saucony-fastwitch-9'},
#  {'name': 'Under Armour Fat Tire 3', 'slug': 'under-armour-fat-tire-3'},
#  {'name': 'Hoka One One Mafate Speed 2',
#   'slug': 'hoka-one-one-mafate-speed-2'},
#  {'name': 'Altra Duo', 'slug': 'altra-duo'},
#  {'name': 'Brooks T7 Racer', 'slug': 'brooks-t7-racer'},
#  {'name': 'Brooks PureFlow 5', 'slug': 'brooks-pureflow'},
#  {'name': 'Brooks Pureflow 6', 'slug': 'brooks-pureflow-6'},
#  {'name': 'Under Armour Charged Bandit 4',
#   'slug': 'under-armour-charged-bandit-4'},
#  {'name': 'Adidas Supernova ST', 'slug': 'adidas-supernova-st'},
#  {'name': 'Hoka One One Napali', 'slug': 'hoka-one-one-napali'},
#  {'name': 'Brooks Levitate 2 LE', 'slug': 'brooks-levitate-2-le'},
#  {'name': 'Hoka One One Clifton 5 Knit',
#   'slug': 'hoka-one-one-clifton-5-knit'},
#  {'name': 'Newton Kismet', 'slug': 'newton-kismet'},
#  {'name': 'Brooks Ghost 7', 'slug': 'brooks-ghost-7'},
#  {'name': 'New Balance FuelCore Sonic', 'slug': 'new-balance-fuelcore-sonic'},
#  {'name': 'Hoka One One Tracer 2', 'slug': 'hoka-one-one-tracer-2'},
#  {'name': 'Adidas Adizero Prime', 'slug': 'adidas-adizero-prime'},
#  {'name': 'Nike Air Max Sequent 4', 'slug': 'nike-air-max-sequent-4'},
#  {'name': 'Brooks Cascadia 13', 'slug': 'brooks-cascadia-13'},
#  {'name': 'Nike Air Zoom Streak LT 4', 'slug': 'nike-air-zoom-streak-lt-4'},
#  {'name': 'Nike Air Max Sequent 3', 'slug': 'nike-air-max-sequent-3'},
#  {'name': 'Adidas Terrex CMTK', 'slug': 'adidas-terrex-cmtk'},
#  {'name': 'Altra Provision 3.0', 'slug': 'altra-provision-3-0'},
#  {'name': 'Asics Metarun', 'slug': 'asics-metarun'},
#  {'name': 'Nike Zoom Vaporfly 4% Flyknit',
#   'slug': 'nike-zoom-vaporfly-4-flyknit'},
#  {'name': 'Vivobarefoot Ultra 3', 'slug': 'vivobarefoot-ultra-3'},
#  {'name': 'Saucony Hurricane 17', 'slug': 'saucony-hurricane'},
#  {'name': 'Brooks Addiction 12', 'slug': 'brooks-addiction'},
#  {'name': 'Nike Odyssey React Shield', 'slug': 'nike-odyssey-react-shield'},
#  {'name': 'Asics Gel Kayano 22', 'slug': 'asics-gel-kayano'},
#  {'name': 'Asics Gel Quantum Infinity', 'slug': 'asics-gel-quantum-infinity'},
#  {'name': 'Hoka One One Elevon', 'slug': 'hoka-one-one-elevon'},
#  {'name': 'New Balance FuelCell Rebel', 'slug': 'new-balance-fuelcell-rebel'},
#  {'name': 'New Balance Fresh Foam Gobi Trail v2',
#   'slug': 'new-balance-fresh-foam-gobi-trail-v2'},
#  {'name': 'Saucony Zealot ISO 3', 'slug': 'saucony-zealot-iso-3'},
#  {'name': 'Asics Gel Cumulus 19', 'slug': 'asics-gel-cumulus-19'},
#  {'name': 'Altra King MT 1.5', 'slug': 'altra-king-mt-15'},
#  {'name': 'Merrell Agility Synthesis Flex',
#   'slug': 'merrell-agility-synthesis-flex'},
#  {'name': 'Asics Gel Sonoma 3', 'slug': 'asics-gel-sonoma-3'},
#  {'name': 'Nike Air Zoom Wildhorse 4', 'slug': 'nike-air-zoom-wildhorse-4'},
#  {'name': 'Vivobarefoot Stealth II', 'slug': 'vivobarefoot-stealth-ii'},
#  {'name': 'Saucony Peregrine 7', 'slug': 'saucony-peregrine-7'},
#  {'name': 'Mizuno Wave Horizon', 'slug': 'mizuno-wave-horizon'},
#  {'name': 'Saucony Shadow 6000', 'slug': 'saucony-shadow-6000'},
#  {'name': 'Adidas Terrex Speed LD', 'slug': 'adidas-terrex-speed-ld'},
#  {'name': 'Altra Lone Peak 3.0', 'slug': 'altra-lone-peak-3-0'},
#  {'name': 'Asics Gel Quantum 360 Knit', 'slug': 'asics-gel-quantum-360-knit'},
#  {'name': 'Brooks Glycerin 14', 'slug': 'brooks-glycerin-14'},
#  {'name': 'Altra Kayenta', 'slug': 'altra-kayenta'},
#  {'name': 'New Balance Leadville v3', 'slug': 'new-balance-1210-v3'},
#  {'name': 'Saucony Type A6', 'slug': 'saucony-type-a'},
#  {'name': 'Inov-8 TerraUltra G 260', 'slug': 'inov-8-terraultra-g-260'},
#  {'name': 'Adidas Questar Trail', 'slug': 'adidas-questar-trail'},
#  {'name': 'Nike Zoom Strike', 'slug': 'nike-zoom-strike'},
#  {'name': 'Nike Air Zoom Structure 19', 'slug': 'nike-air-zoom-structure'},
#  {'name': 'Adidas Terrex Skychaser GTX',
#   'slug': 'adidas-terrex-skychaser-gtx'},
#  {'name': 'New Balance 1500 v4', 'slug': 'new-balance-1500-v4'},
#  {'name': 'Topo Athletic Terraventure 2',
#   'slug': 'topo-athletic-terraventure-2'},
#  {'name': 'Mizuno Wave Rider 19', 'slug': 'mizuno-wave-rider'},
#  {'name': 'Adidas Solar Ride', 'slug': 'adidas-solar-ride'},
#  {'name': 'Altra Olympus 2.0', 'slug': 'altra-olympus'},
#  {'name': 'Under Armour Micro G Assert 6', 'slug': 'armour-micro-g-assert-6'},
#  {'name': 'Puma Hybrid Rocket Runner', 'slug': 'puma-hybrid-rocket-runner'},
#  {'name': 'Mizuno Wave Rider 23', 'slug': 'mizuno-wave-rider-23'},
#  {'name': 'Brooks Glycerin 13', 'slug': 'brooks-glycerin'},
#  {'name': 'Topo Athletic Hydroventure', 'slug': 'topo-athletic-hydroventure'},
#  {'name': 'New Balance Fresh Foam Hierro v3',
#   'slug': 'new-balance-fresh-foam-hierro-v3'},
#  {'name': 'Altra Provision 3.5', 'slug': 'altra-provision-35'},
#  {'name': 'Nike Revolution 4 FlyEase', 'slug': 'nike-revolution-4-flyease'},
#  {'name': 'Topo Athletic Magnifly 2', 'slug': 'topo-athletic-magnifly-2'},
#  {'name': 'Nike Free RN Motion Flyknit 2018',
#   'slug': 'nike-free-rn-motion-flyknit-2018'},
#  {'name': 'Adidas Adizero Sub 2', 'slug': 'adidas-adizero-sub-2'},
#  {'name': 'New Balance 990 v5', 'slug': 'new-balance-990-v5'},
#  {'name': 'New Balance 510 v3', 'slug': 'new-balance-510-v3'},
#  {'name': 'Under Armour Dash RN 2', 'slug': 'under-armour-dash-rn-2'},
#  {'name': 'New Balance Fresh Foam Zante v2',
#   'slug': 'new-balance-fresh-foam-zante'},
#  {'name': 'Nike Air Zoom Structure 20', 'slug': 'nike-air-zoom-structure-20'},
#  {'name': 'Nike Air Zoom Elite 9', 'slug': 'nike-air-zoom-elite-9'},
#  {'name': 'Under Armour Threadborne Slingflex',
#   'slug': 'under-armour-threadborne-slingflex'},
#  {'name': 'Zoot Ultra TT 7.0', 'slug': 'zoot-ultra-tt'},
#  {'name': 'Asics Dynamis', 'slug': 'asics-dynamis'},
#  {'name': 'New Balance Fresh Foam Lazr Hyposkin',
#   'slug': 'new-balance-fresh-foam-lazr-hyposkin'},
#  {'name': 'Reebok Zig Pulse', 'slug': 'reebok-zig-pulse'},
#  {'name': 'Nike Free RN Commuter 2017', 'slug': 'nike-free-rn-commuter-2017'},
#  {'name': 'Topo Athletic Ultrafly', 'slug': 'topo-athletic-ultrafly'},
#  {'name': 'Under Armour Toccoa', 'slug': 'under-armour-toccoa'},
#  {'name': 'On Cloud Waterproof', 'slug': 'on-cloud-waterproof'},
#  {'name': 'New Balance Fresh Foam Cruz Decon',
#   'slug': 'new-balance-fresh-foam-cruz-decon'},
#  {'name': 'Skechers GOmeb Speed 5', 'slug': 'skechers-gomeb-speed-5'},
#  {'name': 'Nike Air Zoom Elite 8', 'slug': 'nike-air-zoom-elite'},
#  {'name': 'Asics Gel Noosa Tri 9', 'slug': 'asics-gel-noosa-tri-9'},
#  {'name': 'New Balance FuelCore Rush v3',
#   'slug': 'new-balance-fuelcore-rush-v3'},
#  {'name': 'Salomon S-Lab Sense 6', 'slug': 'salomon-s-lab-sense-6'},
#  {'name': 'On Cloudventure Waterproof', 'slug': 'on-cloudventure-waterproof'},
#  {'name': 'Skechers GOrun MaxTrail 5 Ultra',
#   'slug': 'skechers-gorun-maxtrail-5-ultra'},
#  {'name': 'Nike LunarEclipse 4', 'slug': 'nike-lunareclipse-4'},
#  {'name': 'Salomon XA Enduro', 'slug': 'salomon-xa-enduro'},
#  {'name': 'Adidas Terrex Agravic GTX', 'slug': 'adidas-terrex-agravic-gtx'},
#  {'name': 'New Balance 940 v2', 'slug': 'new-balance-940'},
#  {'name': 'Brooks Ravenna 7', 'slug': 'brooks-ravenna'},
#  {'name': 'Hoka One One Vanquish 2', 'slug': 'hoka-one-one-vanquish-2'},
#  {'name': 'Under Armour Fat Tire 2', 'slug': 'under-armour-fat-tire-2'},
#  {'name': 'Nike Air Max Dynasty 2', 'slug': 'nike-air-max-dynasty-2'},
#  {'name': 'Newton Distance 6', 'slug': 'newton-distance-6'},
#  {'name': 'Skechers GOrun Ultra Road', 'slug': 'skechers-gorun-ultra-road'},
#  {'name': 'New Balance 880 v6', 'slug': 'new-balance-880-v6'},
#  {'name': 'Puma Jamming', 'slug': 'puma-jamming'},
#  {'name': 'Skechers GOrun 5', 'slug': 'skechers-gorun-5'},
#  {'name': 'Nike Free RN 2018 Shield', 'slug': 'nike-free-rn-2018-shield'},
#  {'name': 'New Balance Fresh Foam Gobi Trail',
#   'slug': 'new-balance-fresh-foam-gobi-trail'},
#  {'name': 'Adidas Cosmic 2.0 SL', 'slug': 'adidas-cosmic-20-sl'},
#  {'name': 'Xero Shoes TerraFlex', 'slug': 'xero-shoes-terraflex'},
#  {'name': 'Nike Dual Fusion X', 'slug': 'nike-dual-fusion-x'},
#  {'name': 'Adidas Galaxy 3', 'slug': 'adidas-galaxy-3'},
#  {'name': 'Nike Air Max Advantage', 'slug': 'nike-air-max-advantage'},
#  {'name': 'Skechers GOrun Forza 3', 'slug': 'skechers-gorun-forza-3'},
#  {'name': 'New Balance FuelCore Coast v3',
#   'slug': 'new-balance-fuelcore-coast-v3'},
#  {'name': 'Mizuno Wave Hitogami 2', 'slug': 'mizuno-wave-hitogami-2'},
#  {'name': 'Nike Air Zoom Vomero 11', 'slug': 'nike-air-zoom-vomero'},
#  {'name': 'Vibram FiveFingers V-Run', 'slug': 'vibram-fivefingers-v-run'},
#  {'name': 'Adidas AlphaBounce RC', 'slug': 'adidas-alphabounce-rc'},
#  {'name': 'Saucony Triumph ISO 3', 'slug': 'saucony-triumph-iso-3'},
#  {'name': 'Altra Lone Peak 3.0 NeoShell Mid',
#   'slug': 'altra-lone-peak-3-0-neoshell-mid'},
#  {'name': 'Mizuno Wave Horizon 2', 'slug': 'mizuno-wave-horizon-2'},
#  {'name': 'Altra Lone Peak 3.0 NeoShell Low',
#   'slug': 'altra-lone-peak-30-neoshell-low'},
#  {'name': 'New Balance Hanzo S', 'slug': 'new-balance-hanzo-s'},
#  {'name': 'Brooks Ravenna 8', 'slug': 'brooks-ravenna-8'},
#  {'name': 'On Cloudrush', 'slug': 'on-cloudrush'},
#  {'name': 'Asics Gel DS Trainer 22', 'slug': 'asics-gel-ds-trainer-22'},
#  {'name': 'Altra One v3', 'slug': 'altra-one-v3'},
#  {'name': 'Asics GT 2000 6 Trail', 'slug': 'asics-gt-2000-6-trail'},
#  {'name': 'Mizuno Wave Creation 20', 'slug': 'mizuno-wave-creation-20'},
#  {'name': 'Inov-8 X-Talon 230', 'slug': 'inov-8-x-talon-230'},
#  {'name': 'Salomon Ultra Pro', 'slug': 'salomon-ultra-pro'},
#  {'name': 'Hoka One One Speedgoat 3 Waterproof',
#   'slug': 'hoka-one-one-speedgoat-3-waterproof'},
#  {'name': 'Adidas Terrex Trailmaker GTX',
#   'slug': 'adidas-terrex-trailmaker-gtx'},
#  {'name': 'Adidas Energy Falcon', 'slug': 'adidas-energy-falcon'},
#  {'name': 'The North Face Endurus TR', 'slug': 'the-north-face-endurus-tr'},
#  {'name': 'New Balance 610 v5', 'slug': 'new-balance-610'},
#  {'name': 'Salomon Sonic Pro', 'slug': 'salomon-sonic-pro'},
#  {'name': 'Brooks Cascadia 13 GTX', 'slug': 'brooks-cascadia-13-gtx'},
#  {'name': 'Under Armour SpeedForm Velociti',
#   'slug': 'under-armour-speedform-velociti'},
#  {'name': 'Vivobarefoot Primus Lite', 'slug': 'vivobarefoot-primus-lite'},
#  {'name': 'Merrell Bare Access Flex 2', 'slug': 'merrell-bare-access-flex-2'},
#  {'name': 'Nike Flex RN 2016', 'slug': 'nike-flex-rn-2016'},
#  {'name': 'Vibram FiveFingers Lontra', 'slug': 'vibram-fivefingers-lontra'},
#  {'name': 'Skechers Flex Appeal', 'slug': 'skechers-flex-appeal'},
#  {'name': 'Adidas Asweerun', 'slug': 'adidas-asweerun'},
#  {'name': 'Asics Gel Kayano 21', 'slug': 'asics-gel-kayano-21'},
#  {'name': 'Brooks Caldera 2', 'slug': 'brooks-caldera-2'},
#  {'name': 'Asics Gel Quantum 360 Knit 2',
#   'slug': 'asics-gel-quantum-360-knit-2'},
#  {'name': 'Hoka One One Stinson 3', 'slug': 'hoka-one-one-stinson-3'},
#  {'name': 'New Balance 860 v5', 'slug': 'new-balance-860-v5'},
#  {'name': 'Puma Carson 2 Knit', 'slug': 'puma-carson-2-knit'},
#  {'name': 'Reebok Fusium Run', 'slug': 'reebok-fusium-run'},
#  {'name': 'Asics Gel Surveyor 5', 'slug': 'asics-gel-surveyor-5'},
#  {'name': 'Hoka One One Stinson ATR 5', 'slug': 'hoka-one-one-stinson-atr-5'},
#  {'name': 'Under Armour Charged Bandit',
#   'slug': 'under-armour-charged-bandit'},
#  {'name': 'Hoka One One Clayton 2', 'slug': 'hoka-one-one-clayton-2'},
#  {'name': 'Hoka One One Clifton 2', 'slug': 'hoka-one-one-clifton'},
#  {'name': 'Salomon S-Lab Ultra', 'slug': 'salomon-s-lab-ultra'},
#  {'name': 'Asics Gel Venture 6 MX', 'slug': 'asics-gel-venture-6-mx'},
#  {'name': 'Skechers GOrun 400', 'slug': 'skechers-gorun-400'},
#  {'name': 'Nike Air Zoom Vomero 10', 'slug': 'nike-air-zoom-vomero-10'},
#  {'name': 'Under Armour Threadborne Blur',
#   'slug': 'under-armour-threadborne-blur'},
#  {'name': 'Salomon Sonic Aero', 'slug': 'salomon-sonic-aero'},
#  {'name': 'Adidas Energy Cloud', 'slug': 'adidas-energy-cloud'},
#  {'name': 'Mizuno Wave Sonic', 'slug': 'mizuno-wave-sonic'},
#  {'name': 'Asics Gel Foundation 12', 'slug': 'asics-gel-foundation'},
#  {'name': 'Asics Gecko XT', 'slug': 'asics-gecko-xt'},
#  {'name': 'On Cloudventure Peak', 'slug': 'on-cloudventure-peak'},
#  {'name': 'Topo Athletic Fli-Lyte 2', 'slug': 'topo-athletic-fli-lyte-2'},
#  {'name': 'Nike Rise React Flyknit', 'slug': 'nike-rise-react-flyknit'},
#  {'name': 'Reebok Endless Road', 'slug': 'reebok-endless-road'},
#  {'name': 'Asics Gel Cumulus 18', 'slug': 'asics-gel-cumulus-18'},
#  {'name': 'New Balance 690 v2 Trail', 'slug': 'new-balance-690-v2-trail'},
#  {'name': 'Asics Gel Pulse 9', 'slug': 'asics-gel-pulse-9'},
#  {'name': 'New Balance 1500 v2', 'slug': 'new-balance-1500'},
#  {'name': 'Mizuno Wave Creation 19', 'slug': 'mizuno-wave-creation-19'},
#  {'name': 'Saucony Excursion TR 11', 'slug': 'saucony-excursion-tr-11'},
#  {'name': 'Salomon XA Elevate GTX', 'slug': 'salomon-xa-elevate-gtx'},
#  {'name': 'Hoka One One Clifton 6', 'slug': 'hoka-one-one-clifton-6'},
#  {'name': 'Adidas Terrex Agravic XT GTX',
#   'slug': 'adidas-terrex-agravic-xt-gtx'},
#  {'name': 'Asics Gel FujiTrabuco 6', 'slug': 'asics-gel-fujitrabuco-6'},
#  {'name': 'Newton Fate', 'slug': 'newton-fate'},
#  {'name': 'New Balance 1260 v6', 'slug': 'new-balance-1260-v6'},
#  {'name': 'Mizuno Wave Hitogami 3', 'slug': 'mizuno-wave-hitogami'},
#  {'name': 'Saucony Kinvara 8', 'slug': 'saucony-kinvara-8'},
#  {'name': 'New Balance Cypher Run', 'slug': 'new-balance-cypher-run'},
#  {'name': 'Hoka One One Evo Carbon Rocket',
#   'slug': 'hoka-one-one-evo-carbon-rocket'},
#  {'name': 'La Sportiva Wildcat 2.0 GTX', 'slug': 'la-sportiva-wildcat-gtx'},
#  {'name': 'Brooks PureConnect 3', 'slug': 'brooks-pureconnect-3'},
#  {'name': 'Nike Air Zoom Odyssey', 'slug': 'nike-air-zoom-odyssey'},
#  {'name': 'Hoka One One Speedgoat', 'slug': 'hoka-one-one-speedgoat'},
#  {'name': 'Reebok Fast Flexweave', 'slug': 'reebok-fast-flexweave'},
#  {'name': 'New Balance FuelCore Sonic v2',
#   'slug': 'new-balance-fuelcore-sonic-v2'},
#  {'name': 'Zoot Del Mar', 'slug': 'zoot-del-mar'},
#  {'name': 'Reebok All Terrain Super 3.0',
#   'slug': 'reebok-all-terrain-super-30'},
#  {'name': 'Nike Zoom Streak 6', 'slug': 'nike-zoom-streak-6'},
#  {'name': 'Vibram FiveFingers V-Trail', 'slug': 'vibram-fivefingers-v-trail'},
#  {'name': 'Under Armour SpeedForm Slingshot 2',
#   'slug': 'under-armour-speedform-slingshot-2'},
#  {'name': 'Inov-8 Roclite 320 GTX', 'slug': 'inov-8-roclite-320-gtx'},
#  {'name': 'Reebok Print Run 3.0', 'slug': 'reebok-print-run-30'},
#  {'name': 'New Balance 1500 v5', 'slug': 'new-balance-1500-v5'},
#  {'name': 'Adidas Solar Blaze', 'slug': 'adidas-solar-blaze'},
#  {'name': 'Adidas AlphaBounce Parley', 'slug': 'adidas-alphabounce-parley'},
#  {'name': 'Adidas Pure Boost ZG', 'slug': 'adidas-pure-boost-zg'},
#  {'name': 'Newton Gravity V', 'slug': 'newton-gravity'},
#  {'name': 'Nike Air Zoom Winflo 5 Run Shield',
#   'slug': 'nike-air-zoom-winflo-5-run-shield'},
#  {'name': 'Under Armour Scorpio', 'slug': 'under-armour-scorpio'},
#  {'name': 'Asics FuzeX Lyte', 'slug': 'asics-fuzex-lyte'},
#  {'name': 'Nike Air Zoom Fly 2', 'slug': 'nike-air-zoom-fly'},
#  {'name': 'Hoka One One Rincon', 'slug': 'hoka-one-one-rincon'},
#  {'name': 'On Cloudflash', 'slug': 'on-cloudflash'},
#  {'name': 'Merrell Agility Peak Flex', 'slug': 'merrell-agility-peak-flex'},
#  {'name': 'New Balance 1400 v3', 'slug': 'new-balance-1400-v3'},
#  {'name': 'Puma NRGY', 'slug': 'puma-nrgy'},
#  {'name': 'New Balance 560 v6', 'slug': 'new-balance-560'},
#  {'name': 'Adidas Supernova Sequence Boost 8',
#   'slug': 'adidas-supernova-sequence-boost'},
#  {'name': 'Saucony Hurricane 16', 'slug': 'saucony-hurricane-16'},
#  {'name': 'Altra Paradigm 4.5', 'slug': 'altra-paradigm-45'},
#  {'name': 'Merrell Trail Glove 4 Knit', 'slug': 'merrell-trail-glove-4-knit'},
#  {'name': 'Newton Distance Elite', 'slug': 'newton-distance-elite'},
#  {'name': 'Adidas Adistar Boost ESM', 'slug': 'adidas-adistar-boost-esm'},
#  {'name': 'Asics GT 4000', 'slug': 'asics-gt-4000'},
#  {'name': 'Adidas Energy Cloud 2', 'slug': 'adidas-energy-cloud-2'},
#  {'name': 'New Balance Summit KOM', 'slug': 'new-balance-summit-kom'},
#  {'name': 'Asics Gel Moya', 'slug': 'asics-gel-moya'},
#  {'name': 'Hoka One One Bondi 4', 'slug': 'hoka-one-one-bondi'},
#  {'name': 'Salomon S-Lab XA Amphib', 'slug': 'salomon-s-lab-xa-amphib'},
#  {'name': 'La Sportiva Uragano GTX', 'slug': 'la-sportiva-uragano-gtx'},
#  {'name': 'Merrell All Out Crush 2', 'slug': 'merrell-all-out-crush-2'},
#  {'name': 'Under Armour SpeedForm Apollo 2',
#   'slug': 'under-armour-speedform-apollo'},
#  {'name': 'Puma Ignite EvoKNIT', 'slug': 'puma-ignite-evoknit'},
#  {'name': 'Asics Gel Pulse 7', 'slug': 'asics-gel-pulse'},
#  {'name': 'Adidas Energy Boost 2 ESM', 'slug': 'adidas-energy-boost-esm'},
#  {'name': 'New Balance Fresh Foam Zante Solas',
#   'slug': 'new-balance-fresh-foam-zante-solas'},
#  {'name': 'Merrell Vapor Glove 2', 'slug': 'merrell-vapor-glove'},
#  {'name': 'Under Armour Fat Tire GTX', 'slug': 'armour-fat-tire-gtx'},
#  {'name': 'Nike Free RN Flyknit 3.0', 'slug': 'nike-free-rn-flyknit-30'},
#  {'name': 'New Balance 510 v4 ', 'slug': 'new-balance-510-v4'},
#  {'name': 'The North Face Rovereto', 'slug': 'the-north-face-rovereto'},
#  {'name': 'Skechers GOrun Fast', 'slug': 'skechers-gorun-fast'},
#  {'name': 'Adidas Duramo 7', 'slug': 'adidas-duramo'},
#  {'name': 'Asics Gel Fortitude 7', 'slug': 'asics-gel-fortitude'},
#  {'name': 'Nike Free RN Distance 2', 'slug': 'nike-free-rn-distance-2'},
#  {'name': 'Saucony Kinvara 7', 'slug': 'saucony-kinvara'},
#  {'name': 'Under Armour Horizon RTT', 'slug': 'under-armour-horizon-rtt'},
#  {'name': 'Adidas Purebounce+ Street', 'slug': 'adidas-purebounce-street'},
#  {'name': 'Topo Athletic Ultraventure', 'slug': 'topo-athletic-ultraventure'},
#  {'name': 'New Balance Minimus Zero v2 Road',
#   'slug': 'new-balance-minimus-road'},
#  {'name': 'Saucony Echelon 5', 'slug': 'saucony-echelon'},
# ...
#  {'name': 'Mizuno Wave Ascend 8', 'slug': 'mizuno-wave-ascend'},
#  {'name': 'Nike Air Zoom Pegasus 34 Shield',
#   'slug': 'nike-air-zoom-pegasus-34-shield'},
#  {'name': 'New Balance FuelCore Nitrel v2',
#   'slug': 'new-balance-fuelcore-nitrel-v2'},
#  {'name': 'Brooks Adrenaline GTS 15', 'slug': 'brooks-adrenaline-gts-15'},
#  {'name': 'New Balance Fresh Foam Gobi Trail v3',
#   'slug': 'new-balance-fresh-foam-gobi-trail-v3'},
#  {'name': 'Saucony Koa TR', 'slug': 'saucony-koa-tr'},
#  {'name': 'On Cloud Terry', 'slug': 'on-cloud-terry'},
#  {'name': 'Adidas Kanadia 7 GTX', 'slug': 'adidas-kanadia-gtx'},
#  {'name': 'Nike Zoom Fly SP Fast', 'slug': 'nike-zoom-fly-sp-fast'},
#  {'name': 'Adidas Vigor Bounce', 'slug': 'adidas-vigor-bounce'},
#  {'name': 'Nike Flex Fury', 'slug': 'nike-flex-fury'},
#  {'name': 'Mizuno Wave Prophecy 8', 'slug': 'mizuno-wave-prophecy-8'},
#  {'name': 'Adidas Climachill Sonic Boost',
#   'slug': 'adidas-climachill-sonic-boost'},
#  {'name': 'Zoot Laguna', 'slug': 'zoot-laguna'},
#  {'name': 'New Balance Vazee Rush', 'slug': 'new-balance-vazee-rush'},
#  {'name': 'New Balance 990 v3', 'slug': 'new-balance-990-v3'},
#  {'name': 'Brooks Mazama', 'slug': 'brooks-mazama'},
#  {'name': 'New Balance 790 v6', 'slug': 'new-balance-790-v6'},
#  {'name': 'Inov-8 Roclite 305', 'slug': 'inov-8-roclite-305'},
#  {'name': 'Skechers GOrun 4', 'slug': 'skechers-gorun'},
#  {'name': 'Salomon Speedtrak', 'slug': 'salomon-speedtrak'},
#  {'name': 'Saucony Omni 15', 'slug': 'saucony-omni-15'},
#  {'name': 'Nike Air Max Tailwind 8', 'slug': 'nike-air-max-tailwind'},
#  {'name': 'New Balance Fresh Foam Cruz v2 Nubuck',
#   'slug': 'new-balance-fresh-foam-cruz-v2-nubuck'},
#  {'name': 'On Cloud 50/50', 'slug': 'on-cloud-5050'},
#  {'name': 'Hoka One One Mach 2', 'slug': 'hoka-one-one-mach-2'},
#  {'name': 'Skechers GOrun MaxRoad 3 Ultra',
#   'slug': 'skechers-gorun-maxroad-3-ultra'},
#  {'name': 'Under Armour Micro G Pursuit Twist',
#   'slug': 'under-armour-micro-g-pursuit-twist'},
#  {'name': 'Asics Gel Flux 4', 'slug': 'asics-gel-flux-4'},
#  {'name': 'Hoka One One Clayton', 'slug': 'hoka-one-one-clayton'},
#  {'name': 'Merrell Bare Access Arc 4', 'slug': 'merrell-bare-access-arc'},
#  {'name': 'Adidas Questar Boost', 'slug': 'adidas-questar-boost'},
#  {'name': 'Salomon Snowcross CS', 'slug': 'salomon-snowcross-cs'},
#  {'name': 'Nike Air Zoom Winflo 3', 'slug': 'nike-air-zoom-winflo-3'},
#  {'name': 'Mizuno Wave Creation 17', 'slug': 'mizuno-wave-creation'},
#  {'name': 'Nike Air VaporMax Flyknit Moc 2',
#   'slug': 'nike-air-vapormax-flyknit-moc-2'},
#  {'name': 'Asics Gel Zaraca 4', 'slug': 'asics-gel-zaraca'},
#  {'name': 'Asics Gel Zaraca 4', 'slug': 'asics-gel-zaraca'},
#  {'name': 'Saucony Breakthru 3', 'slug': 'saucony-breakthru-3'},
#  {'name': 'Adidas AlphaEdge 4D', 'slug': 'adidas-alphaedge-4d'},
#  {'name': 'Adidas Response Boost 2', 'slug': 'adidas-response-boost'},
#  {'name': 'Mizuno Wave Rider 18', 'slug': 'mizuno-wave-rider-18'},
#  {'name': 'Saucony Echelon 6', 'slug': 'saucony-echelon-6'},
#  {'name': 'Jordan Grind', 'slug': 'jordan-grind'},
#  {'name': 'Merrell Agility Peak Flex 2 E-Mesh',
#   'slug': 'merrell-agility-peak-flex-2-e-mesh'},
#  {'name': 'Nike Zoom Strike 2 ', 'slug': 'nike-zoom-strike-2'},
#  {'name': 'The North Face Corvara', 'slug': 'the-north-face-corvara'},
#  {'name': 'Hoka One One Vanquish 3', 'slug': 'hoka-one-one-vanquish-3'},
#  {'name': 'Adidas Speedfactory AM4LDN', 'slug': 'adidas-speedfactory-am4ldn'},
#  {'name': 'Brooks Neuro 3', 'slug': 'brooks-neuro-3'},
#  {'name': 'Asics MetaRide', 'slug': 'asics-metaride'},
#  {'name': 'Adidas Response Boost Trail',
#   'slug': 'adidas-response-boost-trail'},
#  {'name': 'Altra Vanish-R', 'slug': 'altra-vanish-r'},
#  {'name': 'La Sportiva Ultra Raptor GTX',
#   'slug': 'la-sportiva-ultra-raptor-gtx'},
#  {'name': 'Nike Air Max Sequent 2', 'slug': 'nike-air-max-sequent-2'},
#  {'name': 'New Balance Vazee Prism', 'slug': 'new-balance-vazee-prism'},
#  {'name': 'Inov-8 Roadclaw 275', 'slug': 'inov-8-roadclaw-275'},
#  {'name': 'Merrell Trail Glove 4 Shield',
#   'slug': 'merrell-trail-glove-4-shield'},
#  {'name': 'Brooks Cascadia 11', 'slug': 'brooks-cascadia'},
#  {'name': 'Hoka One One Tracer', 'slug': 'hoka-one-one-tracer'},
#  {'name': 'Adidas Duramo 8', 'slug': 'adidas-duramo-8'},
#  {'name': 'Merrell All Out Crush Tough Mudder 2 BOA',
#   'slug': 'merrell-all-out-crush-tough-mudder-2-boa'},
#  {'name': 'Salomon Speedcross 3 CS', 'slug': 'salomon-speedcross-cs'},
#  {'name': 'Adidas Pure Boost Go LTD', 'slug': 'adidas-pure-boost-go-ltd'},
#  {'name': 'Reebok Zigwild TR 2', 'slug': 'reebok-zigwild-tr-2'},
#  {'name': 'Skechers GOrun Mojo', 'slug': 'skechers-gorun-mojo'},
#  {'name': 'Vivobarefoot Primus Lux', 'slug': 'vivobarefoot-primus-lux'},
#  {'name': 'Merrell All Out Crush', 'slug': 'merrell-all-out-crush'},
#  {'name': 'Inov-8 Mudclaw 275', 'slug': 'inov-8-mudclaw-275'},
#  {'name': 'Asics Gel Kayano 24 Lite-Show',
#   'slug': 'asics-gel-kayano-24-lite-show'},
#  {'name': 'Asics GT 2000 3', 'slug': 'asics-gt-2000-3'},
#  {'name': 'Adidas Adizero Prime Parley',
#   'slug': 'adidas-adizero-prime-parley'},
#  {'name': 'New Balance 1340 v2', 'slug': 'new-balance-1340'},
#  {'name': 'Asics Gel Sendai 3', 'slug': 'asics-gel-sendai'},
#  {'name': 'Saucony Ride 7', 'slug': 'saucony-ride-7'},
#  {'name': 'Under Armour Threadborne Slingwrap',
#   'slug': 'under-armour-threadborne-slingwrap'},
#  {'name': 'Newton Distance 7', 'slug': 'newton-distance-7'},
#  {'name': 'Brooks Adrenaline ASR 14', 'slug': 'brooks-adrenaline-asr-14'},
#  {'name': 'Hoka One One Speed Instinct',
#   'slug': 'hoka-one-one-speed-instinct'},
#  {'name': 'Hoka One One Infinite', 'slug': 'hoka-one-one-infinite'},
#  {'name': 'Asics Gel Nimbus 21 Lite-Show',
#   'slug': 'asics-gel-nimbus-21-lite-show'},
#  {'name': 'Altra Impulse', 'slug': 'altra-impulse'},
#  {'name': 'Nike Lunar Skyelux', 'slug': 'nike-lunar-skyelux'},
#  {'name': 'Adidas Ultra Boost ST Parley',
#   'slug': 'adidas-ultra-boost-st-parley'},
#  {'name': 'Adidas Supernova Glide Boost 7',
#   'slug': 'adidas-supernova-glide-boost-7'},
#  {'name': 'New Balance 690 v4', 'slug': 'new-balance-690'},
#  {'name': 'Asics Amplica', 'slug': 'asics-amplica'},
#  {'name': 'Nike Free Flyknit 3.0', 'slug': 'nike-free-flyknit-3-0'},
#  {'name': 'Inov-8 Roadclaw 275 v2', 'slug': 'inov-8-roadclaw-275-v2'},
#  {'name': 'Adidas Element Race', 'slug': 'adidas-element-race'},
#  {'name': 'Mizuno Wave Universe 5', 'slug': 'mizuno-wave-universe'},
#  {'name': 'Adidas Vengeful', 'slug': 'adidas-vengeful'},
#  {'name': 'Saucony Hurricane ISO 3', 'slug': 'saucony-hurricane-iso-3'},
#  {'name': 'Saucony Switchback ISO', 'slug': 'saucony-switchback-iso'},
#  {'name': 'Brooks Ricochet LE', 'slug': 'brooks-ricochet-le'},
#  {'name': 'Under Armour Speedform Fortis 2',
#   'slug': 'under-armour-speedform-fortis-2'},
#  {'name': 'Altra Superior 3.0', 'slug': 'altra-superior-3-0'},
#  {'name': 'Nike Zoom All Out Low 2', 'slug': 'nike-zoom-all-out-low-2'},
#  {'name': 'New Balance 890 v5', 'slug': 'new-balance-890'},
#  {'name': 'Adidas Pure Boost LTD', 'slug': 'adidas-pure-boost-ltd'},
#  {'name': 'Salomon S-Lab Speed 2', 'slug': 'salomon-s-lab-speed-2'},
#  {'name': 'Salomon Sonic RA Pro', 'slug': 'salomon-sonic-ra-pro'},
#  {'name': 'Under Armour SpeedForm Intake 2',
#   'slug': 'under-armour-speedform-intake-2'},
#  {'name': 'Inov-8 X-Talon 200', 'slug': 'inov-8-x-talon-200'},
#  {'name': 'Reebok Harmony Road 2', 'slug': 'reebok-harmony-road-2'},
#  {'name': 'Saucony Peregrine 8 Ice+', 'slug': 'saucony-peregrine-8-ice'},
#  {'name': 'Nike Dual Fusion Run 3', 'slug': 'nike-dual-fusion-rn'},
#  {'name': 'Nike Free 4.0', 'slug': 'nike-free-4-0'},
#  {'name': 'Vibram FiveFingers Spyridon MR',
#   'slug': 'vibram-fivefingers-spyridon-mr'},
#  {'name': 'Mizuno Wave Paradox 3', 'slug': 'mizuno-wave-paradox-3'},
#  {'name': 'New Balance 1400 v5', 'slug': 'new-balance-1400-v5'},
#  {'name': 'Salomon Supercross', 'slug': 'salomon-supercross'},
#  {'name': 'Asics GT 3000 5', 'slug': 'asics-gt-3000-5'},
#  {'name': 'Nike Air VaporMax Flyknit Utility',
#   'slug': 'nike-air-vapormax-flyknit-utility'},
#  {'name': 'New Balance 890 v7', 'slug': 'new-balance-890-v7'},
#  {'name': 'Nike LunarGlide 6', 'slug': 'nike-lunarglide-6'},
#  {'name': 'Asics Gel Cumulus 16', 'slug': 'asics-gel-cumulus-16'},
#  {'name': 'Brooks Dyad 9', 'slug': 'brooks-dyad-9'},
#  {'name': 'Nike Air Zoom Streak LT 3', 'slug': 'nike-air-zoom-streak-lt'},
#  {'name': 'Saucony Hurricane ISO 2', 'slug': 'saucony-hurricane-iso'},
#  {'name': 'Saucony Kineta Relay Reflex',
#   'slug': 'saucony-kineta-relay-reflex'},
#  {'name': 'La Sportiva Helios 2.0', 'slug': 'la-sportiva-helios-2-0'},
#  {'name': 'Reebok OSR Grasse Road', 'slug': 'reebok-osr-grasse-road'},
#  {'name': 'New Balance 5000 v2', 'slug': 'new-balance-5000'},
#  {'name': 'Merrell Agility Peak Flex 3',
#   'slug': 'merrell-agility-peak-flex-3'},
#  {'name': 'Nike Wild Trail', 'slug': 'nike-wild-trail'},
#  {'name': 'Under Armour Scorpio 2', 'slug': 'armour-scorpio-2'},
#  {'name': 'Altra Lone Peak 2.5', 'slug': 'altra-lone-peak'},
#  {'name': 'Brooks Dyad 8', 'slug': 'brooks-dyad'},
#  {'name': 'Salomon XT Hornet', 'slug': 'salomon-xt-hornet'},
#  {'name': 'Vibram FiveFingers EL-X', 'slug': 'vibram-fivefingers-el-x'},
#  {'name': 'Skechers GOrun Forza 2', 'slug': 'skechers-gorun-forza-2'},
#  {'name': 'Inov-8 Terraclaw 250', 'slug': 'inov-8-terraclaw-250'},
#  {'name': 'Vibram FiveFingers Trek Ascent Insulated',
#   'slug': 'vibram-fivefingers-trek-ascent-insulated'},
#  {'name': 'Salomon Sense Pro 2', 'slug': 'salomon-sense-pro-2'},
#  {'name': 'Salomon S-Lab Sense 7', 'slug': 'salomon-s-lab-sense-7'},
#  {'name': 'Salomon Sense Pro 3', 'slug': 'salomon-sense-pro-3'},
#  {'name': 'Inov-8 Trailroc 245', 'slug': 'inov-8-trailroc-245'},
#  {'name': 'Asics Gel Phoenix 8', 'slug': 'asics-gel-phoenix-8'},
#  {'name': 'Nike Dual Fusion Run 2', 'slug': 'nike-dual-fusion-run-2'},
#  {'name': 'Adidas Run Lux Clima', 'slug': 'adidas-run-lux-clima'},
#  {'name': 'New Balance Fresh Foam Arishi Sport',
#   'slug': 'new-balance-fresh-foam-arishi-sport'},
#  {'name': 'Under Armour Micro G Pursuit SE',
#   'slug': 'under-armour-micro-g-pursuit-se'},
#  {'name': 'Under Armour Threadborne Fortis 3',
#   'slug': 'under-armour-threadborne-fortis-3'},
#  {'name': 'Asics Gel Pulse 10', 'slug': 'asics-gel-pulse-10'},
#  {'name': 'Saucony Cohesion TR 11', 'slug': 'saucony-cohesion-tr-11'},
#  {'name': 'Merrell Bare Access Flex Knit',
#   'slug': 'merrell-bare-access-flex-knit'},
#  {'name': 'Asics Gel Cumulus 20 MX', 'slug': 'asics-gel-cumulus-20-mx'},
#  {'name': 'Saucony Guide ISO 2 TR', 'slug': 'saucony-guide-iso-2-tr'},
#  {'name': 'Mizuno Wave Creation 18', 'slug': 'mizuno-wave-creation-18'},
#  {'name': 'Under Armour Charged Bandit 2',
#   'slug': 'under-armour-charged-bandit-2'},
#  {'name': '361 Degrees Meraki', 'slug': '361-degrees-meraki'},
#  {'name': 'New Balance FuelCore Coast v4',
#   'slug': 'new-balance-fuelcore-coast-v4'},
#  {'name': 'Under Armour HOVR Guardian', 'slug': 'under-armour-hovr-guardian'},
#  {'name': 'Nike Air Zoom Elite 10', 'slug': 'nike-air-zoom-elite-10'},
#  {'name': 'Salomon Sonic RA Max 2', 'slug': 'salomon-sonic-ra-max-2'},
#  {'name': 'Nike LunarEpic Flyknit Shield',
#   'slug': 'nike-lunarepic-flyknit-shield'},
#  {'name': 'Nike LunarEpic Flyknit Shield',
#   'slug': 'nike-lunarepic-flyknit-shield'},
#  {'name': 'Hoka One One Cavu 2', 'slug': 'hoka-one-one-cavu-2'},
#  {'name': 'La Sportiva Lycan', 'slug': 'la-sportiva-lycan'},
#  {'name': 'Asics GT 1000 5', 'slug': 'asics-gt-1000-5'},
#  {'name': 'Hoka One One Huaka', 'slug': 'hoka-one-one-huaka'},
#  {'name': 'Asics Noosa FF', 'slug': 'asics-noosa-ff'},
#  {'name': 'Hoka One One Speed Instinct 2',
#   'slug': 'hoka-one-one-speed-instinct-2'},
#  {'name': 'Salomon Speedcross Vario 2', 'slug': 'salomon-speedcross-vario-2'},
#  {'name': 'New Balance Vazee Pace v2', 'slug': 'new-balance-vazee-pace-v2'},
#  {'name': 'Skechers GOrun Ride 6', 'slug': 'skechers-gorun-ride-6'},
#  {'name': 'Asics Gel Quantum 180 2 MX', 'slug': 'asics-gel-quantum-180-2-mx'},
#  {'name': 'Asics Gel Fortify', 'slug': 'asics-gel-fortify'},
#  {'name': 'Salomon Speedcross Vario', 'slug': 'salomon-speedcross-vario'},
#  {'name': 'Adidas Pulseboost HD', 'slug': 'adidas-pulseboost-hd'},
#  {'name': 'Brooks Cascadia 10', 'slug': 'brooks-cascadia-10'},
#  {'name': 'Zoot Ultra Kalani 3.0', 'slug': 'zoot-ultra-kalani'},
#  {'name': 'Under Armour Fuse FST', 'slug': 'under-armour-fuse-fst'},
#  {'name': 'New Balance 1080 v5', 'slug': 'new-balance-1080-v5'},
#  {'name': 'Newton Motion 7', 'slug': 'newton-motion-7'},
#  {'name': 'Nike Flex RN 2015', 'slug': 'nike-flex-rn'},
#  {'name': 'Reebok PT Prime Runner FC', 'slug': 'reebok-pt-prime-runner-fc'},
#  {'name': 'Nike Air Zoom Pegasus 35 FlyEase',
#   'slug': 'nike-air-zoom-pegasus-35-flyease'},
#  {'name': 'La Sportiva Wildcat 3.0', 'slug': 'la-sportiva-wildcat'},
#  {'name': 'Hoka One One Challenger 3 ATR',
#   'slug': 'hoka-one-one-challenger-3-atr'},
#  {'name': 'Adidas Alphaboost Parley', 'slug': 'adidas-alphaboost-parley'},
#  {'name': 'Newton Distance 8', 'slug': 'newton-distance-8'},
#  {'name': 'Topo Athletic Ultrafly 2', 'slug': 'topo-athletic-ultrafly-2'},
#  {'name': 'Salomon Fellraiser', 'slug': 'salomon-fellraiser'},
#  {'name': 'Reebok Driftium', 'slug': 'reebok-driftium'},
#  {'name': 'Vibram FiveFingers Trek Ascent',
#   'slug': 'vibram-fivefingers-trek-ascent'},
#  {'name': 'Under Armour SpeedForm Gemini 2.1',
#   'slug': 'under-armour-speedform-gemini-2-1'},
#  {'name': 'Asics Gel Contend 2', 'slug': 'asics-gel-contend-2'},
#  {'name': 'Reebok Floatride Run Fast Pro',
#   'slug': 'reebok-floatride-run-fast-pro'},
#  {'name': 'Hoka One One Mafate Speed', 'slug': 'hoka-one-one-mafate-speed'},
#  {'name': 'Skechers GOmeb Speed 3', 'slug': 'skechers-gomeb-speed'},
#  {'name': 'Merrell All Out Charge', 'slug': 'merrell-all-out-charge'},
#  {'name': 'Merrell Road Glove 3', 'slug': 'merrell-road-glove'},
#  {'name': 'Skechers GOrun Ride 4', 'slug': 'skechers-gorun-ride-4'},
#  {'name': 'Asics Gel Kenun MX SP', 'slug': 'asics-gel-kenun-mx-sp'},
#  {'name': 'Nike Air Zoom All Out Flyknit', 'slug': 'nike-air-zoom-flyknit'},
#  {'name': 'Nike Zoom Fly 3', 'slug': 'nike-zoom-fly-3'},
#  {'name': 'Asics GT 1000 7 SP', 'slug': 'asics-gt-1000-7-sp'},
#  {'name': 'Reebok Flashfilm', 'slug': 'reebok-flashfilm'},
#  {'name': 'Altra Torin 2.0', 'slug': 'altra-torin'},
#  {'name': 'Vibram FiveFingers Seeya', 'slug': 'vibram-fivefingers-seeya'},
#  {'name': 'Merrell Bare Access Flex E-Mesh',
#   'slug': 'merrell-bare-access-flex-e-mesh'},
#  {'name': 'Adidas Terrex Fast R GTX', 'slug': 'adidas-terrex-fast-r-gtx'},
#  {'name': 'Inov-8 X-Claw 275', 'slug': 'inov-8-x-claw-275'},
#  {'name': 'Salomon Speedcross Pro 2', 'slug': 'salomon-speedcross-pro-2'},
#  {'name': 'Mizuno Wave Inspire 11', 'slug': 'mizuno-wave-inspire-11'},
#  {'name': 'Skechers GOrun 6', 'slug': 'skechers-gorun-6'},
#  {'name': 'Adidas Falcon Elite 5', 'slug': 'adidas-falcon-elite'},
#  {'name': 'Salomon S-Lab Sense Ultra', 'slug': 'salomon-slab-sense-ultra'},
#  {'name': 'Topo Athletic MT-3', 'slug': 'topo-athletic-mt-3'},
#  {'name': 'New Balance Cypher Run v2', 'slug': 'new-balance-cypher-run-v2'},
#  {'name': 'Newton Fate 4', 'slug': 'newton-fate-4'},
#  {'name': 'Reebok Sublite Escape 3.0', 'slug': 'reebok-sublite-escape'},
#  {'name': 'Nike Free Train Instinct', 'slug': 'nike-free-train-instinct'},
#  {'name': 'Mizuno Wave Tenjin', 'slug': 'mizuno-wave-tenjin'},
#  {'name': 'Skechers GOtrail', 'slug': 'skechers-gotrail'},
#  {'name': 'Under Armour SpeedForm Slingride',
#   'slug': 'armour-speedform-slingride'},
#  {'name': 'Mizuno Wave Enigma 6', 'slug': 'mizuno-wave-enigma-6'},
#  {'name': 'New Balance 720 v3', 'slug': 'new-balance-720'},
#  {'name': 'Asics Noosa FF 2', 'slug': 'asics-noosa-ff-2'},
#  {'name': 'Asics Gel Nimbus 20 Lite-Show',
#   'slug': 'asics-gel-nimbus-20-lite-show'},
#  {'name': 'Salomon X-Scream 3D', 'slug': 'salomon-x-scream-3d'},
#  {'name': 'Altra Paradigm 2.0', 'slug': 'altra-paradigm-2-0'},
#  {'name': 'Skechers GOmeb Razor 2', 'slug': 'skechers-gomeb-razor-2'},
#  {'name': 'Asics Comutora', 'slug': 'asics-comutora'},
#  {'name': 'Asics Gel Quantum 360 Shift',
#   'slug': 'asics-gel-quantum-360-shift'},
#  ...]

# %%
# Check correct number of shoes scraped
len(shoe_list)
# Out:
# 2066

# %%
df = pd.DataFrame(shoe_list)
df
# Out:
#                                      name                                 slug
# 0                Nike Air Zoom Pegasus 35             nike-air-zoom-pegasus-35
# 1                         Brooks Ghost 11                      brooks-ghost-11
# 2                     Asics Gel Kayano 25                  asics-gel-kayano-25
# 3                Brooks Adrenaline GTS 19             brooks-adrenaline-gts-19
# 4                      Adidas Ultra Boost                   adidas-ultra-boost
# 5                                On Cloud                             on-cloud
# 6                     Asics Gel Venture 6                  asics-gel-venture-6
# 7                    Hoka One One Bondi 6                 hoka-one-one-bondi-6
# 8                      Nike Downshifter 7                   nike-downshifter-7
# 9                      Asics Gel Excite 6                   asics-gel-excite-6
# 10                  Merrell Trail Glove 4                merrell-trail-glove-4
# 11               Nike Air Zoom Pegasus 36             nike-air-zoom-pegasus-36
# 12                 Nike Air Zoom Winflo 6               nike-air-zoom-winflo-6
# 13               Brooks Adrenaline GTS 18             brooks-adrenaline-gts-18
# 14                        Xero Shoes Prio                      xero-shoes-prio
# 15                     New Balance 990 v4                   new-balance-990-v4
# 16                Nike Zoom Pegasus Turbo              nike-zoom-pegasus-turbo
# 17                    Asics Gel Contend 5                  asics-gel-contend-5
# 18                    Asics Gel Nimbus 21                  asics-gel-nimbus-21
# 19                Nike Epic React Flyknit              nike-epic-react-flyknit
# 20                          Nike Zoom Fly                        nike-zoom-fly
# 21                      Nike Revolution 4                    nike-revolution-4
# 22                     Brooks Glycerin 16                   brooks-glycerin-16
# 23                     Brooks Glycerin 17                   brooks-glycerin-17
# 24                 Hoka One One Clifton 5               hoka-one-one-clifton-5
# 25              Nike Free RN Flyknit 2018            nike-free-rn-flyknit-2018
# 26              Nike Epic React Flyknit 2            nike-epic-react-flyknit-2
# 27                   Adidas Pure Boost Go                 adidas-pure-boost-go
# 28                        Altra Escalante                      altra-escalante
# 29                   Adidas Ultraboost 19                 adidas-ultraboost-19
# ...                                   ...                                  ...
# 2036              Dynafit Feline Vertical              dynafit-feline-vertical
# 2037             Salomon Speedcross 5 GTX             salomon-speedcross-5-gtx
# 2038                   Mizuno WaveKnit C1                   mizuno-waveknit-c1
# 2039                   Scott Kinabalu GTX                   scott-kinabalu-gtx
# 2040                    Dynafit Speed MTN                    dynafit-speed-mtn
# 2041              Mizuno Wave Mujin 5 GTX              mizuno-wave-mujin-5-gtx
# 2042                Mizuno Wave Ibuki GTX                mizuno-wave-ibuki-gtx
# 2043             Under Armour Horizon BPF             under-armour-horizon-bpf
# 2044                       Puma Speed 500                       puma-speed-500
# 2045                 Mizuno Wave Daichi 4                 mizuno-wave-daichi-4
# 2046                       Scott Kinabalu                       scott-kinabalu
# 2047                   Mizuno WaveKnit S1                   mizuno-waveknit-s1
# 2048                     Skechers GOrun 7                     skechers-gorun-7
# 2049             Mizuno Wave Daichi 4 GTX             mizuno-wave-daichi-4-gtx
# 2050                  Mizuno Wave Polaris                  mizuno-wave-polaris
# 2051                 Mizuno Wave Equate 3                 mizuno-wave-equate-3
# 2052             Dynafit Trailbreaker GTX             dynafit-trailbreaker-gtx
# 2053                  Mizuno Wave Prodigy                  mizuno-wave-prodigy
# 2054          Dynafit Feline Vertical Pro          dynafit-feline-vertical-pro
# 2055          Saucony Zealot ISO 3 Reflex          saucony-zealot-iso-3-reflex
# 2056  New Balance FuelCore Sonic Viz Pack  new-balance-fuelcore-sonic-viz-pack
# 2057    New Balance Fresh Foam Cruz Sport    new-balance-fresh-foam-cruz-sport
# 2058                  Icebug DTS 3 BUGrip                  icebug-dts-3-bugrip
# 2059                Icebug DTS 3 RB9X GTX                icebug-dts-3-rb9x-gtx
# 2060                Dynafit Speed MTN GTX                dynafit-speed-mtn-gtx
# 2061          Puma Speed Ignite Netfit 2            puma-speed-ignite-netfit-2
# 2062               Puma Speed 1000 Ignite               puma-speed-1000-ignite
# 2063             Puma Speed 600 Ignite 3               puma-speed-600-ignite-3
# 2064                   Inov-8 Oroc 280 v2                   inov-8-oroc-280-v2
# 2065              Puma Speed 300 Ignite 3              puma-speed-300-ignite-3
#
# [2066 rows x 2 columns]

# %%
# Export to csv
df.to_csv('shoe_list.csv', index=False)
